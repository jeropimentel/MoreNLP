# %%
import numpy as np
import string

np.random.seed(1234)

# %%
initial = {} # start of a phrase
first_order = {} # second word only
second_order = {}

# %%
def remove_punctuation(s):
  return s.translate(str.maketrans('','', string.punctuation))

# %%
# Out:
# File ‘robert_frost.txt’ already there; not retrieving.

# %%
def add2dict(d, k, v):
  if k not in d:
    
    d[k] = []
  d[k].append(v)

# %%
for line in open('robert_frost.txt'):
  tokens = remove_punctuation(line.rstrip().lower()).split()

  T = len(tokens)
  for i in range(T):
    t = tokens[i]
    if i == 0:
      # measure the distribution of the first word
      initial[t] = initial.get(t, 0.) + 1
    else:
      t_1 = tokens[i-1]
      if i == T - 1:
        # measure probability of ending the line
        add2dict(second_order, (t_1, t), 'END')
      if i == 1:
        # measure distribution of second word
        # given only first word
        add2dict(first_order, t_1, t)
      else:
        t_2 = tokens[i-2]
        add2dict(second_order, (t_2, t_1), t)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-97ed8474e790> in <module>()
# ----> 1 for line in open('robert_frost.txt'):
#       2   tokens = remove_punctuation(line.rstrip().lower()).split()
#       3
#       4   T = len(tokens)
#       5   for i in range(T):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'robert_frost.txt'

# %%
# normalize the distributions
initial_total = sum(initial.values())
for t, c in initial.items():
    initial[t] = c / initial_total

# %%
# convert [cat, cat, cat, dog, dog, dog, dog, mouse, ...]
# into {cat: 0.5, dog: 0.4, mouse: 0.1}

def list2pdict(ts):
  # turn each list of possibilities into a dictionary of probabilities
  d = {}
  n = len(ts)
  for t in ts:
    d[t] = d.get(t, 0.) + 1
  for t, c in d.items():
    d[t] = c / n
  return d

# %%
for t_1, ts in first_order.items():
  # replace list with dictionary of probabilities
  first_order[t_1] = list2pdict(ts)


for k, ts in second_order.items():
  second_order[k] = list2pdict(ts)

print(first_order)
print(second_order)
# Out:
# {'two': {'roads': 0.25, 'miles': 0.125, 'oldbelievers': 0.125, 'winds': 0.125, 'weeks': 0.125, 'of': 0.125, 'at': 0.125}, 'and': {'sorry': 0.015503875968992248, 'be': 0.007751937984496124, 'looked': 0.007751937984496124, 'having': 0.007751937984496124, 'both': 0.015503875968992248, 'that': 0.015503875968992248, 'miles': 0.015503875968992248, 'would': 0.007751937984496124, 'dropped': 0.007751937984496124, 'further': 0.007751937984496124, 'when': 0.007751937984496124, 'tell': 0.023255813953488372, 'the': 0.031007751937984496, 'caught': 0.007751937984496124, 'put': 0.015503875968992248, 'threw': 0.007751937984496124, 'birds': 0.007751937984496124, 'suddenly': 0.007751937984496124, 'scurf': 0.007751937984496124, 'since': 0.015503875968992248, 'whats': 0.007751937984496124, 'many': 0.007751937984496124, 'blew': 0.007751937984496124, 'stamped': 0.007751937984496124, 'sometimes': 0.007751937984496124, 'some': 0.007751937984496124, 'then': 0.023255813953488372, 'came': 0.007751937984496124, 'this': 0.015503875968992248, 'politician': 0.007751937984496124, 'thatd': 0.007751937984496124, 'rode': 0.007751937984496124, 'if': 0.015503875968992248, 'from': 0.007751937984496124, 'i': 0.031007751937984496, 'he': 0.007751937984496124, 'full': 0.007751937984496124, 'experts': 0.007751937984496124, 'built': 0.007751937984496124, 'thats': 0.007751937984496124, 'spoke': 0.015503875968992248, 'anyway': 0.007751937984496124, 'had': 0.007751937984496124, 'how': 0.007751937984496124, 'taken': 0.007751937984496124, 'lie': 0.007751937984496124, 'left': 0.007751937984496124, 'stroked': 0.007751937984496124, 'a': 0.015503875968992248, 'me': 0.007751937984496124, 'between': 0.007751937984496124, 'wont': 0.007751937984496124, 'hes': 0.007751937984496124, 'his': 0.007751937984496124, 'nothing': 0.007751937984496124, 'better': 0.007751937984496124, 'kick': 0.007751937984496124, 'carried': 0.007751937984496124, 'thought': 0.007751937984496124, 'swollen': 0.015503875968992248, 'hold': 0.007751937984496124, 'all': 0.015503875968992248, 'fell': 0.007751937984496124, 'set': 0.007751937984496124, 'sit': 0.015503875968992248, 'bring': 0.007751937984496124, 'push': 0.007751937984496124, 'those': 0.015503875968992248, 'sproutlands': 0.007751937984496124, 'perhaps': 0.015503875968992248, 'see': 0.007751937984496124, 'dangle': 0.007751937984496124, 'disappeared': 0.007751937984496124, 'below': 0.007751937984496124, 'what': 0.007751937984496124, 'come': 0.007751937984496124, 'begin': 0.007751937984496124, 'build': 0.007751937984496124, 'in': 0.015503875968992248, 'theres': 0.007751937984496124, 'stifling': 0.007751937984496124, 'got': 0.007751937984496124, 'lift': 0.007751937984496124, 'give': 0.007751937984496124, 'fight': 0.007751937984496124, 'such': 0.007751937984496124, 'moon': 0.007751937984496124, 'jupiter': 0.007751937984496124, 'save': 0.007751937984496124, 'nation': 0.007751937984496124, 'though': 0.007751937984496124, 'now': 0.007751937984496124, 'wheres': 0.007751937984496124, 'shell': 0.007751937984496124, 'no': 0.007751937984496124, 'end': 0.007751937984496124, 'after': 0.007751937984496124, 'we': 0.007751937984496124, 'like': 0.007751937984496124, 'youre': 0.007751937984496124, 'turn': 0.007751937984496124, 'not': 0.007751937984496124, 'last': 0.007751937984496124}, 'to': {'where': 0.02, 'watch': 0.04, 'stop': 0.02, 'ask': 0.02, 'say': 0.04, 'carry': 0.02, 'think': 0.02, 'make': 0.12, 'everything': 0.02, 'spare': 0.02, 'see': 0.1, 'turn': 0.02, 'undo': 0.02, 'let': 0.02, 'go': 0.02, 'shut': 0.02, 'bring': 0.02, 'entertain': 0.02, 'find': 0.02, 'send': 0.02, 'such': 0.02, 'wonder': 0.02, 'no': 0.02, 'tell': 0.02, 'stand': 0.02, 'reconnoitre': 0.02, 'set': 0.02, 'blow': 0.02, 'ridgely': 0.02, 'the': 0.04, 'curl': 0.02, 'call': 0.02, 'which': 0.02, 'be': 0.02, 'drag': 0.02, 'come': 0.02, 'live': 0.02, 'break': 0.02}, 'then': {'took': 0.08333333333333333, 'leaf': 0.08333333333333333, 'shook': 0.08333333333333333, 'that': 0.08333333333333333, 'he': 0.0833333333 ...
# {('two', 'roads'): {'diverged': 1.0}, ('roads', 'diverged'): {'in': 1.0}, ('diverged', 'in'): {'a': 1.0}, ('in', 'a'): {'yellow': 0.07142857142857142, 'wood': 0.07142857142857142, 'window': 0.07142857142857142, 'packing': 0.07142857142857142, 'byroad': 0.07142857142857142, 'family': 0.07142857142857142, 'new': 0.07142857142857142, 'row': 0.07142857142857142, 'time': 0.07142857142857142, 'town': 0.07142857142857142, 'book': 0.07142857142857142, 'smother': 0.07142857142857142, 'glass': 0.14285714285714285}, ('yellow', 'wood'): {'END': 1.0}, ('a', 'yellow'): {'wood': 1.0}, ('and', 'sorry'): {'i': 1.0}, ('sorry', 'i'): {'could': 0.5, 'ever': 0.5}, ('i', 'could'): {'not': 0.2, 'END': 0.2, 'have': 0.2, 'see': 0.3, 'do': 0.1}, ('could', 'not'): {'travel': 0.5, 'say': 0.5}, ('travel', 'both'): {'END': 1.0}, ('not', 'travel'): {'both': 1.0}, ('and', 'be'): {'one': 0.5, 'whole': 0.5}, ('be', 'one'): {'traveler': 1.0}, ('one', 'traveler'): {'long': 1.0}, ('traveler', 'long'): {'i': 1.0}, ('i', 'stood'): {'END': 1.0}, ('long', 'i'): {'stood': 0.5, 'lay': 0.5}, ('and', 'looked'): {'down': 1.0}, ('looked', 'down'): {'one': 0.5, 'the': 0.5}, ('down', 'one'): {'as': 0.5, 'street': 0.5}, ('one', 'as'): {'far': 1.0}, ('as', 'far'): {'as': 1.0}, ('far', 'as'): {'i': 0.5, 'we': 0.5}, ('as', 'i'): {'could': 0.25, 'am': 0.25, 'do': 0.25, 'say': 0.25}, ('to', 'where'): {'it': 1.0}, ('where', 'it'): {'bent': 0.16666666666666666, 'ended': 0.16666666666666666, 'fell': 0.16666666666666666, 'wants': 0.16666666666666666, 'came': 0.16666666666666666, 'is': 0.16666666666666666}, ('it', 'bent'): {'in': 1.0}, ('bent', 'in'): {'the': 1.0}, ('the', 'undergrowth'): {'END': 1.0}, ('in', 'the'): {'undergrowth': 0.021739130434782608, 'village': 0.021739130434782608, 'stars': 0.021739130434782608, 'confusion': 0.021739130434782608, 'excited': 0.021739130434782608, 'scene': 0.021739130434782608, 'river': 0.021739130434782608, 'cold': 0.043478260869565216, 'town': 0.021739130434782608, 'warrant': 0.021739130434782608, 'stable': 0.021739130434782608, 'huse': 0.021739130434782608, 'tail': 0.021739130434782608, 'dark': 0.043478260869565216, 'mountain': 0.021739130434782608, 'box': 0.021739130434782608, 'night': 0.021739130434782608, 'bedroom': 0.021739130434782608, 'cellar': 0.15217391304347827, 'joints': 0.021739130434782608, 'light': 0.021739130434782608, 'room': 0.021739130434782608, 'attic': 0.043478260869565216, 'grass': 0.021739130434782608, 'rain': 0.021739130434782608, 'sun': 0.021739130434782608, 'empty': 0.021739130434782608, 'open': 0.021739130434782608, 'kitchen': 0.021739130434782608, 'weather': 0.021739130434782608, 'playhouse': 0.021739130434782608, 'instep': 0.021739130434782608, 'newcut': 0.021739130434782608, 'plowed': 0.021739130434782608, 'bushy': 0.021739130434782608, 'heat': 0.021739130434782608, 'yard': 0.021739130434782608}, ('then', 'took'): {'the': 1.0}, ('took', 'the'): {'other': 0.25, 'one': 0.25, 'long': 0.25, 'hall': 0.25}, ('the', 'other'): {'as': 1.0}, ('other', 'as'): {'just': 1.0}, ('as', 'just'): {'as': 1.0}, ('as', 'fair'): {'END': 1.0}, ('just', 'as'): {'fair': 0.2, 'fast': 0.4, 'empty': 0.2, 'well': 0.2}, ('and', 'having'): {'perhaps': 1.0}, ('having', 'perhaps'): {'the': 1.0}, ('perhaps', 'the'): {'better': 1.0}, ('better', 'claim'): {'END': 1.0}, ('the', 'better'): {'claim': 1.0}, ('because', 'it'): {'was': 1.0}, ('it', 'was'): {'grassy': 0.07692307692307693, 'to': 0.07692307692307693, 'the': 0.15384615384615385, 'all': 0.07692307692307693, 'END': 0.07692307692307693, 'there': 0.07692307692307693, 'proclaimed': 0.07692307692307693, 'cut': 0.07692307692307693, 'raining': 0.07692307692307693, 'coming': 0.07692307692307693, 'long': 0.07692307692307693, 'bad': 0.07692307692307693}, ('was', 'grassy'): {'and': 1.0}, ('grassy', 'and'): {'wanted': 1.0}, ('wanted', 'wear'): {'END': 1.0}, ('and', 'wanted'): {'wear': 1.0}, ('though', 'as'): {'for': 1.0}, ('as', 'for'): {'that': 0.6666666666666666, 'the': 0.3333333333333333}, ('for', 'that'):  ...

# %%
def sample_word(d):
  # print "d:", d
  p0 = np.random.random()
  # print "p0:", p0
  cumulative = 0
  for t, p in d.items():
    cumulative += p
    if p0 < cumulative:
      return t
  assert(False) # should never get here

# %%
for t, p in second_order.items():
  print(t,p)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# ('mormon', 'swimming') {'in': 1.0}
# ('swimming', 'in') {'it': 1.0}
# ('but', 'you') {'have': 0.5, 'see': 0.5}
# ('you', 'have') {'said': 0.3333333333333333, 'three': 0.3333333333333333, 'the': 0.3333333333333333}
# ('have', 'said') {'it': 1.0}
# ('said', 'it') {'and': 0.5, 'isnt': 0.5}
# ('it', 'and') {'were': 0.5, 'besides': 0.5}
# ('and', 'were') {'off': 1.0}
# ('were', 'off') {'to': 1.0}
# ('off', 'to') {'find': 1.0}
# ('to', 'find') {'it': 0.25, 'out': 0.25, 'or': 0.25, 'yourself': 0.25}
# ('old', 'as') {'i': 1.0}
# ('i', 'am') {'im': 0.2, 'a': 0.2, 'END': 0.4, 'sure': 0.2}
# ('am', 'im') {'going': 1.0}
# ('let', 'myself') {'END': 0.5, 'in': 0.5}
# ('be', 'dragged') {'by': 1.0}
# ('dragged', 'by') {'you': 1.0}
# ('by', 'you') {'all': 1.0}
# ('you', 'all') {'over': 1.0}
# ('over', 'everywhere') {'END': 1.0}
# ('i', 'thought') {'you': 0.14285714285714285, 'for': 0.14285714285714285, 'the': 0.2857142857142857, 'i': 0.2857142857142857, 'twas': 0.14285714285714285}
# ('thought', 'you') {'were': 1.0}
# ('you', 'were') {'a': 0.5, 'END': 0.5}
# ('a', 'guide') {'END': 0.6666666666666666, 'direct': 0.3333333333333333}
# ('were', 'a') {'guide': 0.5, 'mans': 0.5}
# ('am', 'a') {'guide': 1.0}
# ('and', 'thats') {'why': 0.5, 'not': 0.5}
# ('thats', 'why') {'i': 1.0}
# ('why', 'i') {'cant': 0.5, 'ever': 0.5}
# ('cant', 'decently') {'refuse': 1.0}
# ('refuse', 'you') {'END': 1.0}
# ('decently', 'refuse') {'you': 1.0}
# ('we', 'made') {'a': 1.0}
# ('a', 'day') {'of': 0.3333333333333333, 'END': 0.6666666666666666}
# ('day', 'of') {'it': 1.0}
# ('it', 'out') {'of': 1.0}
# ('ascending', 'to') {'descend': 1.0}
# ('to', 'descend') {'to': 1.0}
# ('to', 'reascend') {'END': 1.0}
# ('descend', 'to') {'reascend': 1.0}
# ('the', 'old') {'man': 0.16666666666666666, 'captains': 0.16666666666666666, 'girl': 0.16666666666666666, 'ones': 0.16666666666666666, 'stock': 0.16666666666666666, 'place': 0.16666666666666666}
# ('man', 'seriously') {'took': 1.0}
# ('seriously', 'took') {'his': 1.0}
# ('his', 'bearings') {'END': 1.0}
# ('took', 'his') {'bearings': 1.0}
# ('and', 'spoke') {'his': 0.5, 'of': 0.5}
# ('spoke', 'his') {'doubts': 1.0}
# ('his', 'doubts') {'in': 1.0}
# ('doubts', 'in') {'every': 1.0}
# ('open', 'place') {'END': 1.0}
# ('every', 'open') {'place': 1.0}
# ('we', 'came') {'out': 0.6666666666666666, 'here': 0.3333333333333333}
# ('came', 'out') {'on': 0.5, 'of': 0.5}
# ('a', 'lookoff') {'where': 1.0}
# ('lookoff', 'where') {'we': 1.0}
# ('we', 'faced') {'END': 1.0}
# ('a', 'cliff') {'and': 1.0}
# ('cliff', 'and') {'on': 1.0}
# ('and', 'on') {'the': 1.0}
# ('the', 'cliff') {'a': 1.0}
# ('cliff', 'a') {'bottle': 1.0}
# ('bottle', 'painted') {'END': 1.0}
# ('a', 'bottle') {'painted': 1.0}
# ('or', 'stained') {'by': 1.0}
# ('stained', 'by') {'vegetation': 1.0}
# ('by', 'vegetation') {'from': 1.0}
# ('from', 'above') {'END': 1.0}
# ('vegetation', 'from') {'above': 1.0}
# ('a', 'likeness') {'to': 1.0}
# ('likeness', 'to') {'surprise': 1.0}
# ('to', 'surprise') {'the': 1.0}
# ('surprise', 'the') {'thrilly': 1.0}
# ('thrilly', 'tourist') {'END': 1.0}
# ('the', 'thrilly') {'tourist': 1.0}
# ('well', 'if') {'i': 1.0}
# ('i', 'havent') {'brought': 0.5, 'had': 0.5}
# ('havent', 'brought') {'you': 1.0}
# ('brought', 'you') {'to': 1.0}
# ('you', 'to') {'the': 0.75, 'cool': 0.25}
# ('the', 'fountain') {'END': 0.5, 'just': 0.5}
# ('at', 'least') {'ive': 0.3333333333333333, 'to': 0.3333333333333333, 'with': 0.3333333333333333}
# ('least', 'ive') {'brought': 1.0}
# ('ive', 'brought') {'you': 1.0}
# ('famous', 'bottle') {'END': 1.0}
# ('the', 'famous') {'bottle': 1.0}
# ('i', 'wont') {'accept': 0.5, 'be': 0.5}
# ('wont', 'accept') {'the': 1.0}
# ('accept', 'the') {'substitute': 1.0}
# ('the', 'substitute') {'its': 1.0}
# ('its', 'empty') {'END': 1.0}
# ('substitute', 'its') {'empty': 1.0}
# ('sos', 'everything') {'END': 1.0}
# ('i', 'want') {'my': 0.25, 'to': 0.75}
# ('my', 'fountain') {'END': 1.0}
# ('want', 'my') {'fountain': 1.0}
# ('guess', 'youd') {'find': 1.0}
# ('youd', 'find') {'the': 1.0}
# ('find', 'the') {'fountain': 1.0}
# ('fountain', 'just') {'as': 1.0}
# ('as', 'empty') {'END': 1.0}
# ('and', 'anyway') {'this': 1.0}
# ('anyway', 'this') {'tells': 1.0}
# ('this', 'tells') {'me': 1.0}
# ('tells', 'me') {'where': 1.0}
# ('where', 'i') {'am': 0.3333333333333333, 'show': 0.3333333333333333, 'was': 0.3333333333333333}
# ('hadnt', 'you') {'long': 1.0}
# ('you', 'long') {'suspected': 1.0}
# ('long', 'suspected') {'where': 1.0}
# ('suspected', 'where') {'you': 1.0}
# ('where', 'you') {'were': 0.5, 'are': 0.5}
# ('you', 'mean') {'miles': 0.25, 'oh': 0.25, 'thats': 0.25, 'shes': 0.25}
# ('mean', 'miles') {'from': 1.0}
# ('miles', 'from') {'that': 1.0}
# ('mormon', 'settlement') {'END': 1.0}
# ('that', 'mormon') {'settlement': 1.0}
# ('look', 'here') {'you': 1.0}
# ('here', 'you') {'treat': 0.5, 'are': 0.5}
# ('you', 'treat') {'your': 1.0}
# ('treat', 'your') {'guide': 1.0}
# ('your', 'guide') {'with': 1.0}
# ('guide', 'with') {'due': 1.0}
# ('due', 'respect') {'END': 1.0}
# ('with', 'due') {'respect': 1.0}
# ('if', 'you') {'dont': 0.25, 'can': 0.25, 'ask': 0.25, 'want': 0.25}
# ('you', 'dont') {'want': 0.2, 'like': 0.2, 'know': 0.4, 'believe': 0.2}
# ('dont', 'want') {'to': 1.0}
# ('to', 'spend') {'the': 1.0}
# ('spend', 'the') {'night': 1.0}
# ('night', 'outdoors') {'END': 1.0}
# ('i', 'vow') {'we': 1.0}
# ('vow', 'we') {'must': 1.0}
# ('we', 'must') {'be': 0.5, 'in': 0.5}
# ('be', 'near') {'the': 1.0}
# ('near', 'the') {'place': 0.5, 'window': 0.5}
# ('from', 'where') {'END': 1.0}
# ('place', 'from') {'where': 1.0}
# ('the', 'two') {'converging': 1.0}
# ('two', 'converging') {'slides': 1.0}
# ('converging', 'slides') {'the': 1.0}
# ('the', 'avalanches') {'END': 1.0}
# ('slides', 'the') {'avalanches': 1.0}
# ('on', 'marshall') {'look': 1.0}
# ('marshall', 'look') {'like': 1.0}
# ('look', 'like') {'donkeys': 0.3333333333333333, 'me': 0.3333333333333333, 'you': 0.3333333333333333}
# ('donkeys', 'ears') {'END': 0.5, 'suggest': 0.5}
# ('like', 'donkeys') {'ears': 1.0}
# ('we', 'may') {'as': 1.0}
# ('may', 'as') {'well': 1.0}
# ('well', 'see') {'that': 1.0}
# ('see', 'that') {'and': 0.3333333333333333, 'you': 0.3333333333333333, 'theres': 0.3333333333333333}
# ('that', 'and') {'save': 0.5, 'sure': 0.5}
# ('and', 'save') {'the': 0.5, 'for': 0.5}
# ('save', 'the') {'day': 1.0}
# ('dont', 'donkeys') {'ears': 1.0}
# ('ears', 'suggest') {'we': 1.0}
# ('suggest', 'we') {'shake': 1.0}
# ('we', 'shake') {'our': 1.0}
# ('our', 'own') {'END': 1.0}
# ('shake', 'our') {'own': 1.0}
# ('for', 'gods') {'sake': 1.0}
# ('gods', 'sake') {'arent': 1.0}
# ('sake', 'arent') {'you': 1.0}
# ('you', 'fond') {'of': 1.0}
# ('fond', 'of') {'viewing': 0.5, 'nice': 0.5}
# ('viewing', 'nature') {'END': 1.0}
# ('of', 'viewing') {'nature': 1.0}
# ('dont', 'like') {'nature': 1.0}
# ('like', 'nature') {'all': 1.0}
# ('nature', 'all') {'you': 1.0}
# ('all', 'you') {'like': 0.5, 'want': 0.5}
# ('you', 'like') {'is': 1.0}
# ('is', 'books') {'END': 1.0}
# ('like', 'is') {'books': 1.0}
# ('what', 'signify') {'a': 1.0}
# ('signify', 'a') {'donkeys': 1.0}
# ('a', 'donkeys') {'cars': 1.0}
# ('donkeys', 'cars') {'and': 1.0}
# ('and', 'bottle') {'END': 1.0}
# ('cars', 'and') {'bottle': 1.0}
# ('however', 'natural') {'give': 1.0}
# ('natural', 'give') {'you': 1.0}
# ('give', 'you') {'your': 0.3333333333333333, 'a': 0.3333333333333333, 'what': 0.3333333333333333}
# ('your', 'books') {'END': 1.0}
# ('you', 'your') {'books': 1.0}
# ('well', 'then') {'right': 0.5, 'its': 0.5}
# ('then', 'right') {'here': 1.0}
# ('right', 'here') {'is': 1.0}
# ('here', 'is') {'where': 1.0}
# ('i', 'show') {'you': 1.0}
# ('you', 'books') {'END': 1.0}
# ('show', 'you') {'books': 0.25, 'how': 0.25, 'in': 0.25, 'here': 0.25}
# ('come', 'straight') {'down': 1.0}
# ('straight', 'down') {'off': 1.0}
# ('down', 'off') {'this': 1.0}
# ('off', 'this') {'mountain': 1.0}
# ('this', 'mountain') {'just': 1.0}
# ('mountain', 'just') {'as': 1.0}
# ('we', 'can') {'fall': 0.3333333333333333, 'just': 0.3333333333333333, 'hold': 0.3333333333333333}
# ('can', 'fall') {'and': 1.0}
# ('fall', 'and') {'keep': 1.0}
# ('and', 'keep') {'abouncing': 1.0}
# ('keep', 'abouncing') {'on': 1.0}
# ('abouncing', 'on') {'our': 1.0}
# ('our', 'feet') {'END': 1.0}
# ('on', 'our') {'feet': 1.0}
# ('its', 'hell') {'for': 1.0}
# ('hell', 'for') {'knees': 1.0}
# ('for', 'knees') {'unless': 1.0}
# ('knees', 'unless') {'done': 1.0}
# ('done', 'hellforleather') {'END': 1.0}
# ('unless', 'done') {'hellforleather': 1.0}
# ('be', 'ready') {'i': 1.0}
# ('ready', 'i') {'thought': 1.0}
# ('thought', 'for') {'almost': 1.0}
# ('almost', 'anything') {'END': 1.0}
# ('for', 'almost') {'anything': 1.0}
# ('we', 'struck') {'a': 1.0}
# ('struck', 'a') {'road': 1.0}
# ('a', 'road') {'i': 1.0}
# ('didnt', 'recognize') {'END': 1.0}
# ('i', 'didnt') {'recognize': 0.25, 'know': 0.25, 'always': 0.25, 'relish': 0.25}
# ('but', 'welcomed') {'for': 1.0}
# ('welcomed', 'for') {'the': 1.0}
# ('the', 'chance') {'to': 0.5, 'END': 0.5}
# ('chance', 'to') {'lave': 1.0}
# ('to', 'lave') {'my': 1.0}
# ('my', 'shoes') {'END': 1.0}
# ('lave', 'my') {'shoes': 1.0}
# ('in', 'dust') {'once': 1.0}
# ('dust', 'once') {'more': 1.0}
# ('once', 'more') {'we': 0.5, 'before': 0.5}
# ('more', 'we') {'followed': 1.0}
# ('we', 'followed') {'this': 1.0}
# ('followed', 'this') {'a': 1.0}
# ('a', 'mile') {'END': 1.0}
# ('this', 'a') {'mile': 1.0}
# ('perhaps', 'to') {'where': 1.0}
# ('it', 'ended') {'at': 1.0}
# ('ended', 'at') {'a': 1.0}
# ('a', 'house') {'END': 0.375, 'deserted': 0.125, 'stripped': 0.125, 'that': 0.25, 'in': 0.125}
# ('at', 'a') {'house': 0.3333333333333333, 'farm': 0.3333333333333333, 'times': 0.3333333333333333}
# ('didnt', 'know') {'was': 0.5, 'he': 0.5}
# ('know', 'was') {'there': 1.0}
# ('was', 'there') {'it': 0.3333333333333333, 'END': 0.3333333333333333, 'anything': 0.3333333333333333}
# ('there', 'it') {'was': 1.0}
# ('to', 'bring') {'me': 1.0}
# ('bring', 'me') {'to': 1.0}
# ('to', 'for') {'broadboard': 1.0}
# ('broadboard', 'paneling') {'END': 1.0}
# ('for', 'broadboard') {'paneling': 1.0}
# ('i', 'never') {'saw': 0.5, 'could': 0.25, 'heard': 0.25}
# ('never', 'saw') {'so': 0.25, 'before': 0.25, 'a': 0.25, 'this': 0.25}
# ('saw', 'so') {'good': 1.0}
# ('so', 'good') {'a': 0.5, 'at': 0.5}
# ('good', 'a') {'house': 1.0}
# ('house', 'deserted') {'END': 1.0}
# ('excuse', 'me') {'if': 1.0}
# ('me', 'if') {'i': 1.0}
# ('i', 'ask') {'you': 1.0}
# ('ask', 'you') {'in': 1.0}
# ('you', 'in') {'a': 0.3333333333333333, 'the': 0.3333333333333333, 'that': 0.3333333333333333}
# ('a', 'window') {'END': 1.0}
# ('that', 'happens') {'to': 1.0}
# ('happens', 'to') {'be': 1.0}
# ('be', 'broken') {'davis': 1.0}
# ('davis', 'said') {'END': 1.0}
# ('broken', 'davis') {'said': 1.0}
# ('the', 'outside') {'doors': 1.0}
# ('outside', 'doors') {'as': 1.0}
# ('doors', 'as') {'yet': 1.0}
# ('as', 'yet') {'have': 0.5, 'so': 0.5}
# ('yet', 'have') {'held': 1.0}
# ('have', 'held') {'against': 1.0}
# ('against', 'us') {'END': 1.0}
# ('held', 'against') {'us': 1.0}
# ('to', 'introduce') {'you': 1.0}
# ('introduce', 'you') {'to': 1.0}
# ('the', 'people') {'END': 1.0}
# ('who', 'used') {'to': 1.0}
# ('used', 'to') {'live': 0.3333333333333333, 'sing': 0.3333333333333333, 'build': 0.3333333333333333}
# ('live', 'here') {'they': 1.0}
# ('here', 'they') {'were': 1.0}
# ('were', 'robinsons') {'END': 1.0}
# ('you', 'must') {'have': 0.14285714285714285, 'be': 0.42857142857142855, 'go': 0.2857142857142857, 'not': 0.14285714285714285}
# ('have', 'heard') {'of': 0.5, 'END': 0.5}
# ('heard', 'of') {'clara': 0.5, 'a': 0.5}
# ('clara', 'robinson') {'END': 1.0}
# ('of', 'clara') {'robinson': 1.0}
# ('the', 'poetess') {'who': 0.5, 'had': 0.5}
# ('poetess', 'who') {'wrote': 1.0}
# ('who', 'wrote') {'the': 1.0}
# ('wrote', 'the') {'book': 1.0}
# ('the', 'book') {'of': 1.0}
# ('of', 'verses') {'END': 1.0}
# ('book', 'of') {'verses': 1.0}
# ('had', 'it') {'published': 1.0}
# ('it', 'published') {'it': 1.0}
# ('published', 'it') {'was': 1.0}
# ('all', 'about') {'END': 0.5, 'when': 0.5}
# ('the', 'posies') {'on': 1.0}
# ('posies', 'on') {'her': 1.0}
# ('on', 'her') {'inner': 0.3333333333333333, 'outer': 0.3333333333333333, 'heel': 0.3333333333333333}
# ('inner', 'windowsill') {'END': 1.0}
# ('her', 'inner') {'windowsill': 1.0}
# ('the', 'birds') {'on': 0.5, 'and': 0.5}
# ('birds', 'on') {'her': 1.0}
# ('outer', 'windowsill') {'END': 1.0}
# ('her', 'outer') {'windowsill': 1.0}
# ('and', 'how') {'she': 0.3333333333333333, 'much': 0.3333333333333333, 'many': 0.3333333333333333}
# ('how', 'she') {'tended': 0.5, 'had': 0.5}
# ('she', 'tended') {'both': 1.0}
# ('tended', 'both') {'or': 1.0}
# ('both', 'or') {'had': 1.0}
# ('or', 'had') {'them': 1.0}
# ('them', 'tended') {'END': 1.0}
# ('had', 'them') {'tended': 1.0}
# ('she', 'never') {'tended': 1.0}
# ('never', 'tended') {'anything': 1.0}
# ('anything', 'herself') {'END': 1.0}
# ('tended', 'anything') {'herself': 1.0}
# ('she', 'was') {'shut': 1.0}
# ('was', 'shut') {'in': 1.0}
# ('shut', 'in') {'for': 1.0}
# ('in', 'for') {'life': 1.0}
# ('for', 'life') {'she': 1.0}
# ('life', 'she') {'lived': 1.0}
# ('she', 'lived') {'her': 1.0}
# ('her', 'whole') {'END': 1.0}
# ('lived', 'her') {'whole': 1.0}
# ('life', 'long') {'in': 1.0}
# ('long', 'in') {'bed': 0.5, 'that': 0.5}
# ('in', 'bed') {'and': 0.3333333333333333, 'END': 0.6666666666666666}
# ('bed', 'and') {'wrote': 1.0}
# ('and', 'wrote') {'her': 1.0}
# ('wrote', 'her') {'things': 1.0}
# ('her', 'things') {'in': 1.0}
# ('things', 'in') {'bed': 1.0}
# ('ill', 'show') {'you': 1.0}
# ('you', 'how') {'she': 1.0}
# ('she', 'had') {'her': 0.5, 'the': 0.5}
# ('had', 'her') {'sills': 1.0}
# ('sills', 'extended') {'END': 1.0}
# ('her', 'sills') {'extended': 1.0}
# ('to', 'entertain') {'the': 1.0}
# ('entertain', 'the') {'birds': 1.0}
# ('birds', 'and') {'hold': 1.0}
# ('and', 'hold') {'the': 0.6666666666666666, 'his': 0.3333333333333333}
# ('the', 'flowers') {'END': 0.5, 'i': 0.5}
# ('hold', 'the') {'flowers': 0.5, 'door': 0.5}
# ('our', 'business') {'firsts': 1.0}
# ('business', 'firsts') {'up': 1.0}
# ('firsts', 'up') {'attic': 1.0}
# ('up', 'attic') {'with': 0.25, 'mother': 0.25, 'END': 0.25, 'that': 0.25}
# ('attic', 'with') {'her': 1.0}
# ('her', 'books') {'END': 1.0}
# ('with', 'her') {'books': 1.0}
# ('we', 'trod') {'uncomfortably': 1.0}
# ('trod', 'uncomfortably') {'on': 1.0}
# ('uncomfortably', 'on') {'crunching': 1.0}
# ('crunching', 'glass') {'END': 1.0}
# ('on', 'crunching') {'glass': 1.0}
# ('through', 'a') {'house': 1.0}
# ('house', 'stripped') {'of': 1.0}
# ('of', 'everything') {'END': 1.0}
# ('stripped', 'of') {'everything': 1.0}
# ('except', 'it') {'seemed': 1.0}
# ('it', 'seemed') {'the': 1.0}
# ('seemed', 'the') {'poetesss': 1.0}
# ('poetesss', 'poems') {'END': 1.0}
# ('the', 'poetesss') {'poems': 0.3333333333333333, 'heart': 0.3333333333333333, 'life': 0.3333333333333333}
# ('books', 'i') {'should': 1.0}
# ('say', 'if') {'books': 1.0}
# ('if', 'books') {'are': 1.0}
# ('books', 'are') {'what': 1.0}
# ('is', 'needed') {'END': 1.0}
# ('a', 'whole') {'edition': 1.0}
# ('whole', 'edition') {'in': 1.0}
# ('edition', 'in') {'a': 1.0}
# ('packing', 'case') {'END': 1.0}
# ('a', 'packing') {'case': 1.0}
# ('that', 'overflowing') {'like': 1.0}
# ('overflowing', 'like') {'a': 1.0}
# ('a', 'horn') {'of': 1.0}
# ('of', 'plenty') {'END': 1.0}
# ('horn', 'of') {'plenty': 1.0}
# ('or', 'like') {'the': 1.0}
# ('like', 'the') {'poetesss': 0.25, 'dry': 0.25, 'old': 0.25, 'grail': 0.25}
# ('poetesss', 'heart') {'of': 1.0}
# ('of', 'love') {'END': 1.0}
# ('heart', 'of') {'love': 0.5, 'one': 0.5}
# ('had', 'spilled') {'them': 1.0}
# ('spilled', 'them') {'near': 1.0}
# ('them', 'near') {'the': 1.0}
# ('the', 'window') {'toward': 1.0}
# ('window', 'toward') {'the': 1.0}
# ('toward', 'the') {'light': 1.0}
# ('where', 'driven') {'rain': 1.0}
# ('driven', 'rain') {'had': 1.0}
# ('rain', 'had') {'wet': 1.0}
# ('had', 'wet') {'and': 1.0}
# ('wet', 'and') {'swollen': 1.0}
# ('swollen', 'them') {'END': 1.0}
# ('and', 'swollen') {'them': 0.3333333333333333, 'tight': 0.6666666666666666}
# ('to', 'stock') {'a': 1.0}
# ('stock', 'a') {'village': 1.0}
# ('village', 'library') {'END': 1.0}
# ('a', 'village') {'library': 1.0}
# ('unfortunately', 'all') {'of': 1.0}
# ('all', 'of') {'one': 1.0}
# ('kind', 'though') {'END': 1.0}
# ('one', 'kind') {'though': 1.0}
# ('they', 'bad') {'been': 1.0}
# ('bad', 'been') {'brought': 1.0}
# ('been', 'brought') {'home': 1.0}
# ('brought', 'home') {'from': 1.0}
# ('home', 'from') {'some': 0.5, 'work': 0.5}
# ('some', 'publisher') {'END': 1.0}
# ('from', 'some') {'publisher': 1.0}
# ('and', 'taken') {'thus': 1.0}
# ('taken', 'thus') {'into': 1.0}
# ('thus', 'into') {'the': 1.0}
# ('the', 'family') {'END': 0.3333333333333333, 'there': 0.3333333333333333, 'tree': 0.3333333333333333}
# ('into', 'the') {'family': 0.3333333333333333, 'cellar': 0.3333333333333333, 'name': 0.3333333333333333}
# ('boys', 'and') {'bad': 1.0}
# ('and', 'bad') {'hunters': 1.0}
# ('bad', 'hunters') {'had': 1.0}
# ('hunters', 'had') {'known': 1.0}
# ('had', 'known') {'what': 1.0}
# ('known', 'what') {'to': 1.0}
# ('what', 'to') {'do': 1.0}
# ('with', 'stone') {'and': 1.0}
# ('stone', 'and') {'lead': 1.0}
# ('and', 'lead') {'to': 1.0}
# ('lead', 'to') {'unprotected': 1.0}
# ('unprotected', 'glass') {'END': 1.0}
# ('to', 'unprotected') {'glass': 1.0}
# ('shatter', 'it') {'inward': 1.0}
# ('it', 'inward') {'on': 1.0}
# ('inward', 'on') {'the': 1.0}
# ('unswept', 'floors') {'END': 1.0}
# ('the', 'unswept') {'floors': 1.0}
# ('how', 'had') {'the': 1.0}
# ('the', 'tender') {'verse': 1.0}
# ('tender', 'verse') {'escaped': 1.0}
# ('verse', 'escaped') {'their': 1.0}
# ('their', 'outrage') {'END': 1.0}
# ('escaped', 'their') {'outrage': 1.0}
# ('by', 'being') {'invisible': 1.0}
# ('being', 'invisible') {'for': 1.0}
# ('invisible', 'for') {'what': 1.0}
# ('for', 'what') {'it': 0.3333333333333333, 'im': 0.3333333333333333, 'little': 0.3333333333333333}
# ('what', 'it') {'was': 0.3333333333333333, 'is': 0.6666666666666666}
# ('or', 'else') {'by': 0.5, 'mow': 0.5}
# ('else', 'by') {'some': 1.0}
# ('by', 'some') {'remoteness': 0.5, 'mistake': 0.5}
# ('some', 'remoteness') {'that': 1.0}
# ('remoteness', 'that') {'defied': 1.0}
# ('defied', 'them') {'END': 1.0}
# ('that', 'defied') {'them': 1.0}
# ('find', 'out') {'what': 0.5, 'whose': 0.5}
# ('out', 'what') {'to': 1.0}
# ('do', 'to') {'hurt': 0.5, 'me': 0.5}
# ('to', 'hurt') {'a': 1.0}
# ('a', 'poem') {'END': 1.0}
# ('hurt', 'a') {'poem': 0.5, 'hen': 0.5}
# ('yet', 'oh') {'the': 1.0}
# ('oh', 'the') {'tempting': 1.0}
# ('the', 'tempting') {'flatness': 1.0}
# ('tempting', 'flatness') {'of': 1.0}
# ('flatness', 'of') {'a': 1.0}
# ('a', 'book') {'END': 0.5, 'about': 0.5}
# ('to', 'send') {'it': 1.0}
# ('send', 'it') {'sailing': 1.0}
# ('it', 'sailing') {'out': 1.0}
# ('sailing', 'out') {'the': 1.0}
# ('out', 'the') {'attic': 0.5, 'light': 0.5}
# ('attic', 'window') {'END': 1.0}
# ('the', 'attic') {'window': 0.1111111111111111, 'wasps': 0.1111111111111111, 'door': 0.1111111111111111, 'END': 0.1111111111111111, 'stairs': 0.1111111111111111, 'was': 0.1111111111111111, 'let': 0.1111111111111111, 'when': 0.1111111111111111, 'since': 0.1111111111111111}
# ('till', 'it') {'caught': 0.5, 'almost': 0.5}
# ('it', 'caught') {'wind': 1.0}
# ('caught', 'wind') {'and': 1.0}
# ('and', 'opening') {'out': 1.0}
# ('opening', 'out') {'its': 1.0}
# ('its', 'covers') {'END': 1.0}
# ('out', 'its') {'covers': 1.0}
# ('tried', 'to') {'improve': 1.0}
# ('to', 'improve') {'on': 1.0}
# ('improve', 'on') {'sailing': 1.0}
# ('on', 'sailing') {'like': 1.0}
# ('sailing', 'like') {'a': 1.0}
# ('a', 'tile') {'END': 1.0}
# ('by', 'flying') {'like': 1.0}
# ('flying', 'like') {'a': 1.0}
# ('a', 'bird') {'silent': 0.3333333333333333, 'alight': 0.3333333333333333, 'with': 0.3333333333333333}
# ('bird', 'silent') {'in': 1.0}
# ('in', 'flight') {'END': 1.0}
# ('silent', 'in') {'flight': 1.0}
# ('but', 'all') {'the': 1.0}
# ('the', 'burden') {'of': 1.0}
# ('burden', 'of') {'its': 1.0}
# ('of', 'its') {'body': 1.0}
# ('body', 'song') {'END': 1.0}
# ('its', 'body') {'song': 1.0}
# ('only', 'to') {'tumble': 0.5, 'those': 0.5}
# ('to', 'tumble') {'like': 1.0}
# ('tumble', 'like') {'a': 1.0}
# ('stricken', 'bird') {'END': 1.0}
# ('a', 'stricken') {'bird': 1.0}
# ('and', 'lie') {'in': 1.0}
# ('lie', 'in') {'stones': 1.0}
# ('in', 'stones') {'and': 1.0}
# ('stones', 'and') {'bushes': 1.0}
# ('bushes', 'unretrieved') {'END': 1.0}
# ('and', 'bushes') {'unretrieved': 1.0}
# ('books', 'were') {'not': 1.0}
# ('not', 'thrown') {'irreverently': 1.0}
# ('irreverently', 'about') {'END': 1.0}
# ('thrown', 'irreverently') {'about': 1.0}
# ('they', 'simply') {'lay': 1.0}
# ('simply', 'lay') {'where': 1.0}
# ('lay', 'where') {'someone': 1.0}
# ('where', 'someone') {'now': 1.0}
# ('someone', 'now') {'and': 1.0}
# ('now', 'and') {'then': 1.0}
# ('having', 'tried') {'one': 1.0}
# ('tried', 'one') {'had': 1.0}
# ('one', 'had') {'dropped': 1.0}
# ('had', 'dropped') {'it': 1.0}
# ('dropped', 'it') {'at': 1.0}
# ('it', 'at') {'his': 1.0}
# ('and', 'left') {'it': 0.5, 'me': 0.5}
# ('left', 'it') {'lying': 1.0}
# ('it', 'lying') {'where': 1.0}
# ('lying', 'where') {'it': 1.0}
# ('fell', 'rejected') {'END': 1.0}
# ('it', 'fell') {'rejected': 1.0}
# ('here', 'were') {'all': 1.0}
# ('all', 'those') {'the': 1.0}
# ('those', 'the') {'poetesss': 1.0}
# ('poetesss', 'life') {'END': 1.0}
# ('too', 'short') {'to': 0.5, 'END': 0.5}
# ('short', 'to') {'sell': 1.0}
# ('to', 'sell') {'or': 0.3333333333333333, 'END': 0.3333333333333333, 'theyre': 0.3333333333333333}
# ('sell', 'or') {'give': 1.0}
# ('give', 'away') {'END': 1.0}
# ('or', 'give') {'away': 1.0}
# ('take', 'one') {'old': 1.0}
# ('one', 'old') {'davis': 1.0}
# ('davis', 'bade') {'me': 1.0}
# ('me', 'graciously') {'END': 1.0}
# ('bade', 'me') {'graciously': 1.0}
# ('why', 'not') {'take': 1.0}
# ('not', 'take') {'two': 0.5, 'seats': 0.5}
# ('take', 'two') {'or': 1.0}
# ('or', 'three') {'END': 1.0}
# ('two', 'or') {'three': 1.0}
# ('take', 'all') {'you': 1.0}
# ('you', 'want') {'END': 0.3333333333333333, 'the': 0.3333333333333333, 'to': 0.3333333333333333}
# ('goodlooking', 'books') {'like': 1.0}
# ('books', 'like') {'that': 1.0}
# ('like', 'that') {'he': 0.5, 'what': 0.5}
# ('he', 'picked') {'one': 1.0}
# ('one', 'fresh') {'END': 1.0}
# ('picked', 'one') {'fresh': 1.0}
# ('in', 'virgin') {'wrapper': 1.0}
# ('virgin', 'wrapper') {'from': 1.0}
# ('wrapper', 'from') {'deep': 1.0}
# ('from', 'deep') {'in': 1.0}
# ('deep', 'in') {'the': 1.0}
# ('the', 'box') {'END': 1.0}
# ('and', 'stroked') {'it': 1.0}
# ('stroked', 'it') {'with': 1.0}
# ('it', 'with') {'a': 1.0}
# ('hornyhanded', 'kindness') {'END': 1.0}
# ('a', 'hornyhanded') {'kindness': 1.0}
# ('he', 'read') {'in': 1.0}
# ('read', 'in') {'one': 0.5, 'another': 0.5}
# ('in', 'one') {'and': 0.3333333333333333, 'himself': 0.3333333333333333, 'self': 0.3333333333333333}
# ('one', 'and') {'i': 0.5, 'one': 0.5}
# ('i', 'read') {'in': 1.0}
# ('in', 'another') {'END': 1.0}
# ('both', 'either') {'looking': 1.0}
# ('either', 'looking') {'for': 1.0}
# ('for', 'or') {'finding': 1.0}
# ('finding', 'something') {'END': 1.0}
# ('or', 'finding') {'something': 1.0}
# ('attic', 'wasps') {'went': 1.0}
# ('wasps', 'went') {'missing': 1.0}
# ('went', 'missing') {'by': 1.0}
# ('missing', 'by') {'like': 1.0}
# ('like', 'bullets') {'END': 1.0}
# ('by', 'like') {'bullets': 1.0}
# ('was', 'soon') {'satisfied': 1.0}
# ('soon', 'satisfied') {'for': 1.0}
# ('satisfied', 'for') {'the': 1.0}
# ('time', 'being') {'END': 1.0}
# ('home', 'i') {'kept': 0.5, 'dont': 0.5}
# ('kept', 'remembering') {'END': 1.0}
# ('the', 'small') {'book': 1.0}
# ('small', 'book') {'in': 1.0}
# ('book', 'in') {'my': 1.0}
# ('in', 'my') {'pocket': 1.0}
# ('my', 'pocket') {'it': 1.0}
# ('pocket', 'it') {'was': 1.0}
# ('poetess', 'had') {'sighed': 1.0}
# ('had', 'sighed') {'i': 1.0}
# ('sighed', 'i') {'knew': 1.0}
# ('in', 'heaven') {'END': 1.0}
# ('knew', 'in') {'heaven': 1.0}
# ('having', 'eased') {'her': 1.0}
# ('eased', 'her') {'heart': 1.0}
# ('her', 'heart') {'of': 0.5, 'they': 0.5}
# ('more', 'copy') {'END': 1.0}
# ('one', 'more') {'copy': 1.0}
# ('legitimately', 'my') {'demand': 1.0}
# ('my', 'demand') {'upon': 1.0}
# ('upon', 'her') {'END': 1.0}
# ('demand', 'upon') {'her': 1.0}
# ('though', 'slight') {'was': 1.0}
# ('slight', 'was') {'a': 1.0}
# ('a', 'demand') {'she': 1.0}
# ('demand', 'she') {'felt': 1.0}
# ('she', 'felt') {'the': 1.0}
# ('the', 'tug') {'END': 1.0}
# ('felt', 'the') {'tug': 1.0}
# ('in', 'time') {'she': 1.0}
# ('time', 'she') {'would': 1.0}
# ('she', 'would') {'be': 1.0}
# ('be', 'rid') {'of': 1.0}
# ('rid', 'of') {'all': 1.0}
# ('of', 'all') {'her': 0.25, 'be': 0.25, 'the': 0.25, 'this': 0.25}
# ('all', 'her') {'books': 1.0}
# ('i', 'stay') {'END': 1.0}
# ('it', 'isnt') {'as': 0.2, 'going': 0.2, 'grandsir': 0.2, 'END': 0.2, 'worth': 0.2}
# ('isnt', 'as') {'if': 1.0}
# ('there', 'wasnt') {'always': 1.0}
# ('wasnt', 'always') {'hudsons': 1.0}
# ('hudsons', 'bay') {'END': 1.0}
# ('always', 'hudsons') {'bay': 1.0}
# ('fur', 'trade') {'END': 1.0}
# ('the', 'fur') {'trade': 1.0}
# ('small', 'skiff') {'END': 1.0}
# ('a', 'small') {'skiff': 1.0}
# ('and', 'a') {'paddle': 0.3333333333333333, 'trapper': 0.3333333333333333, 'crutch': 0.3333333333333333}
# ('paddle', 'blade') {'END': 1.0}
# ('a', 'paddle') {'blade': 1.0}
# ('can', 'just') {'see': 1.0}
# ('just', 'see') {'my': 0.3333333333333333, 'the': 0.3333333333333333, 'him': 0.3333333333333333}
# ('see', 'my') {'tent': 1.0}
# ('tent', 'pegged') {'END': 1.0}
# ('my', 'tent') {'pegged': 1.0}
# ('and', 'me') {'on': 1.0}
# ('me', 'on') {'the': 1.0}
# ('a', 'trapper') {'looking': 1.0}
# ('trapper', 'looking') {'in': 1.0}
# ('looking', 'in') {'at': 1.0}
# ('in', 'at') {'the': 1.0}
# ('the', 'door') {'END': 0.09090909090909091, 'is': 0.09090909090909091, 'but': 0.09090909090909091, 'they': 0.09090909090909091, 'wide': 0.18181818181818182, 'to': 0.09090909090909091, 'and': 0.18181818181818182, 'shut': 0.09090909090909091, 'though': 0.09090909090909091}
# ('with', 'furs') {'to': 1.0}
# ('furs', 'to') {'sell': 1.0}
# ('names', 'joe') {'END': 1.0}
# ('his', 'names') {'joe': 1.0}
# ('alias', 'john') {'END': 1.0}
# ('and', 'between') {'what': 1.0}
# ('between', 'what') {'he': 1.0}
# ('doesnt', 'know') {'END': 1.0}
# ('he', 'doesnt') {'know': 0.3333333333333333, 'marry': 0.3333333333333333, 'make': 0.3333333333333333}
# ('wont', 'tell') {'END': 1.0}
# ('and', 'wont') {'tell': 1.0}
# ('about', 'where') {'henry': 1.0}
# ('where', 'henry') {'hudsons': 1.0}
# ('hudsons', 'gone') {'END': 1.0}
# ('henry', 'hudsons') {'gone': 1.0}
# ('cant', 'say') {'hes': 1.0}
# ('say', 'hes') {'much': 1.0}
# ('much', 'help') {'END': 1.0}
# ('hes', 'much') {'help': 1.0}
# ('but', 'we') {'get': 1.0}
# ('get', 'on') {'END': 1.0}
# ('we', 'get') {'on': 1.0}
# ('seal', 'yelp') {'END': 1.0}
# ('the', 'seal') {'yelp': 1.0}
# ('on', 'an') {'ice': 0.5, 'impulse': 0.5}
# ('ice', 'cake') {'END': 1.0}
# ('an', 'ice') {'cake': 1.0}
# ('its', 'not') {'men': 0.3333333333333333, 'your': 0.3333333333333333, 'that': 0.3333333333333333}
# ('not', 'men') {'by': 1.0}
# ('men', 'by') {'some': 1.0}
# ('theres', 'not') {'a': 1.0}
# ('a', 'soul') {'END': 1.0}
# ('a', 'windbreak') {'END': 1.0}
# ('for', 'a') {'windbreak': 0.14285714285714285, 'doorsill': 0.14285714285714285, 'fulllength': 0.14285714285714285, 'clock': 0.14285714285714285, 'garden': 0.14285714285714285, 'man': 0.14285714285714285, 'home': 0.14285714285714285}
# ('between', 'me') {'and': 1.0}
# ('me', 'and') {'the': 0.3333333333333333, 'take': 0.3333333333333333, 'see': 0.3333333333333333}
# ('north', 'pole—') {'END': 1.0}
# ('the', 'north') {'pole—': 1.0}
# ('always', 'johnjoe') {'END': 1.0}
# ('except', 'always') {'johnjoe': 1.0}
# ('my', 'french') {'indian': 1.0}
# ('indian', 'esquimaux') {'END': 1.0}
# ('french', 'indian') {'esquimaux': 1.0}
# ('and', 'hes') {'off': 1.0}
# ('hes', 'off') {'setting': 1.0}
# ('setting', 'traps') {'END': 1.0}
# ('off', 'setting') {'traps': 1.0}
# ('himself', 'perhaps') {'END': 1.0}
# ('one', 'himself') {'perhaps': 1.0}
# ('a', 'headshake') {'END': 1.0}
# ('give', 'a') {'headshake': 0.5, 'purer': 0.5}
# ('over', 'so') {'much': 1.0}
# ('much', 'bay') {'END': 1.0}
# ('so', 'much') {'bay': 0.5, 'difference': 0.5}
# ('thrown', 'away') {'END': 1.0}
# ('in', 'snow') {'and': 0.5, 'END': 0.5}
# ('and', 'mist') {'END': 1.0}
# ('snow', 'and') {'mist': 1.0}
# ('doesnt', 'exist') {'END': 1.0}
# ('that', 'doesnt') {'exist': 1.0}
# ('was', 'going') {'to': 1.0}
# ('for', 'god') {'man': 1.0}
# ('god', 'man') {'or': 1.0}
# ('man', 'or') {'beasts': 1.0}
# ('beasts', 'sake') {'END': 1.0}
# ('or', 'beasts') {'sake': 1.0}
# ('yet', 'does') {'perhaps': 1.0}
# ('does', 'perhaps') {'for': 1.0}
# ('perhaps', 'for') {'all': 1.0}
# ('all', 'three') {'END': 1.0}
# ('for', 'all') {'three': 1.0}
# ('ask', 'joe') {'END': 1.0}
# ('dont', 'ask') {'joe': 0.5, 'for': 0.5}
# ('it', 'is') {'to': 0.5, 'END': 0.25, 'it': 0.25}
# ('to', 'him') {'END': 0.6666666666666666, 'you': 0.3333333333333333}
# ('is', 'to') {'him': 0.5, 'me': 0.5}
# ('sometimes', 'dim') {'END': 1.0}
# ('its', 'sometimes') {'dim': 1.0}
# ('it', 'be') {'END': 1.0}
# ('unless', 'it') {'be': 1.0}
# ('its', 'the') {'old': 0.5, 'bones': 0.5}
# ('old', 'captains') {'dark': 1.0}
# ('dark', 'fate') {'END': 1.0}
# ('captains', 'dark') {'fate': 1.0}
# ('who', 'failed') {'to': 1.0}
# ('failed', 'to') {'find': 1.0}
# ('find', 'or') {'force': 1.0}
# ('or', 'force') {'a': 1.0}
# ('a', 'strait') {'END': 1.0}
# ('force', 'a') {'strait': 1.0}
# ('in', 'its') {'twothousandmile': 1.0}
# ('twothousandmile', 'coast') {'END': 1.0}
# ('its', 'twothousandmile') {'coast': 1.0}
# ('and', 'his') {'crew': 0.5, 'brown': 0.5}
# ('his', 'crew') {'left': 1.0}
# ('crew', 'left') {'him': 1.0}
# ('him', 'where') {'be': 1.0}
# ('be', 'failed') {'END': 1.0}
# ('where', 'be') {'failed': 1.0}
# ('and', 'nothing') {'came': 1.0}
# ('nothing', 'came') {'of': 1.0}
# ('came', 'of') {'all': 1.0}
# ('be', 'sailed') {'END': 1.0}
# ('all', 'be') {'sailed': 1.0}
# ('its', 'to') {'say': 1.0}
# ('say', 'you') {'and': 0.5, 'dont': 0.5}
# ('and', 'i—') {'END': 1.0}
# ('you', 'and') {'i—': 0.3333333333333333, 'i': 0.6666666666666666}
# ('to', 'such') {'a': 1.0}
# ('a', 'ghost—') {'END': 1.0}
# ('off', 'here') {'END': 1.0}
# ('the', 'dead') {'race': 0.2, 'had': 0.2, 'were': 0.2, 'are': 0.4}
# ('dead', 'race') {'of': 1.0}
# ('race', 'of') {'the': 1.0}
# ('great', 'auk') {'END': 1.0}
# ('the', 'great') {'auk': 1.0}
# ('and', 'better') {'defeat': 1.0}
# ('defeat', 'almost') {'END': 1.0}
# ('better', 'defeat') {'almost': 1.0}
# ('seen', 'clear') {'END': 1.0}
# ('if', 'seen') {'clear': 1.0}
# ('than', 'lifes') {'victories': 1.0}
# ('lifes', 'victories') {'of': 1.0}
# ('of', 'doubt') {'END': 1.0}
# ('victories', 'of') {'doubt': 1.0}
# ('that', 'need') {'endless': 1.0}
# ('endless', 'talktalk') {'END': 1.0}
# ('need', 'endless') {'talktalk': 1.0}
# ('them', 'out') {'END': 1.0}
# ('make', 'them') {'out': 0.5, 'glad': 0.5}
# ('i', 'staid') {'the': 1.0}
# ('staid', 'the') {'night': 1.0}
# ('night', 'for') {'shelter': 1.0}
# ('for', 'shelter') {'at': 1.0}
# ('shelter', 'at') {'a': 1.0}
# ('a', 'farm') {'END': 0.5, 'not': 0.25, 'that': 0.25}
# ('behind', 'the') {'mountains': 0.3333333333333333, 'barrier': 0.3333333333333333, 'door': 0.3333333333333333}
# ('the', 'mountains') {'with': 1.0}
# ('mountains', 'with') {'a': 1.0}
# ('a', 'mother') {'and': 1.0}
# ('and', 'son') {'END': 1.0}
# ('mother', 'and') {'son': 0.3333333333333333, 'when': 0.3333333333333333, 'neither': 0.3333333333333333}
# ('two', 'oldbelievers') {'they': 1.0}
# ('oldbelievers', 'they') {'did': 1.0}
# ('they', 'did') {'all': 1.0}
# ('did', 'all') {'the': 1.0}
# ('the', 'talking') {'END': 1.0}
# ('mother', 'folks') {'think': 1.0}
# ('folks', 'think') {'a': 1.0}
# ('think', 'a') {'witch': 1.0}
# ('witch', 'who') {'has': 1.0}
# ('who', 'has') {'familiar': 1.0}
# ('familiar', 'spirits') {'END': 1.0}
# ('has', 'familiar') {'spirits': 1.0}
# ('she', 'could') {'call': 1.0}
# ('could', 'call') {'up': 1.0}
# ('call', 'up') {'to': 0.5, 'one': 0.5}
# ('up', 'to') {'pass': 0.2, 'you': 0.2, 'do': 0.2, 'their': 0.2, 'it': 0.2}
# ('to', 'pass') {'a': 0.5, 'by': 0.5}
# ('pass', 'a') {'winter': 1.0}
# ('winter', 'evening') {'END': 0.5, 'walk': 0.5}
# ('a', 'winter') {'evening': 0.3333333333333333, 'eve': 0.3333333333333333, 'garden': 0.3333333333333333}
# ('but', 'wont') {'should': 1.0}
# ('wont', 'should') {'be': 1.0}
# ('should', 'be') {'burned': 1.0}
# ('be', 'burned') {'at': 1.0}
# ('burned', 'at') {'the': 1.0}
# ('the', 'stake') {'or': 1.0}
# ('stake', 'or') {'something': 1.0}
# ('summoning', 'spirits') {'isnt': 1.0}
# ('spirits', 'isnt') {'button': 1.0}
# ('button', 'button') {'END': 1.0}
# ('isnt', 'button') {'button': 1.0}
# ('whos', 'got') {'the': 1.0}
# ('the', 'button') {'i': 1.0}
# ('button', 'i') {'would': 1.0}
# ('them', 'know') {'END': 1.0}
# ('have', 'them') {'know': 1.0}
# ('son', 'mother') {'can': 1.0}
# ('mother', 'can') {'make': 1.0}
# ('can', 'make') {'a': 0.5, 'out': 0.5}
# ('a', 'common') {'table': 1.0}
# ('table', 'rear') {'END': 1.0}
# ('common', 'table') {'rear': 1.0}
# ('kick', 'with') {'two': 1.0}
# ('with', 'two') {'legs': 1.0}
# ('two', 'legs') {'like': 1.0}
# ('legs', 'like') {'an': 1.0}
# ('like', 'an') {'army': 1.0}
# ('army', 'mule') {'END': 1.0}
# ('an', 'army') {'mule': 1.0}
# ('when', 'ive') {'done': 0.5, 'said': 0.5}
# ('ive', 'done') {'it': 1.0}
# ('done', 'it') {'what': 1.0}
# ('it', 'what') {'good': 0.5, 'was': 0.5}
# ('what', 'good') {'have': 0.5, 'you': 0.5}
# ('have', 'i') {'END': 1.0}
# ('good', 'have') {'i': 1.0}
# ('rather', 'than') {'tip': 1.0}
# ('than', 'tip') {'a': 1.0}
# ('tip', 'a') {'table': 1.0}
# ('a', 'table') {'for': 1.0}
# ('table', 'for') {'you': 1.0}
# ('for', 'you') {'let': 1.0}
# ('let', 'me') {'END': 0.2, 'see': 0.2, 'look': 0.2, 'warn': 0.2, 'say': 0.2}
# ('you', 'let') {'me': 1.0}
# ('what', 'ralle') {'the': 1.0}
# ('ralle', 'the') {'sioux': 1.0}
# ('the', 'sioux') {'control': 1.0}
# ('sioux', 'control') {'once': 1.0}
# ('control', 'once') {'told': 1.0}
# ('told', 'me') {'END': 1.0}
# ('once', 'told') {'me': 1.0}
# ('said', 'the') {'dead': 1.0}
# ('dead', 'had') {'souls': 1.0}
# ('had', 'souls') {'but': 1.0}
# ('souls', 'but') {'when': 1.0}
# ('but', 'when') {'i': 0.3333333333333333, 'im': 0.3333333333333333, 'ive': 0.3333333333333333}
# ('asked', 'him') {'END': 1.0}
# ('i', 'asked') {'him': 1.0}
# ('how', 'could') {'that': 1.0}
# ('could', 'that') {'be': 1.0}
# ('that', 'be') {'i': 1.0}
# ('be', 'i') {'thought': 1.0}
# ('thought', 'the') {'dead': 0.5, 'growing': 0.5}
# ('were', 'souls') {'END': 1.0}
# ('dead', 'were') {'souls': 1.0}
# ('he', 'broke') {'my': 1.0}
# ('broke', 'my') {'trance': 1.0}
# ('my', 'trance') {'dont': 1.0}
# ('trance', 'dont') {'that': 1.0}
# ('dont', 'that') {'make': 1.0}
# ('that', 'make') {'you': 1.0}
# ('you', 'suspicious') {'END': 1.0}
# ('make', 'you') {'suspicious': 1.0}
# ('that', 'theres') {'something': 1.0}
# ('theres', 'something') {'the': 0.6666666666666666, 'wrong': 0.3333333333333333}
# ('something', 'the') {'dead': 1.0}
# ('dead', 'are') {'keeping': 1.0}
# ('keeping', 'back') {'END': 1.0}
# ('are', 'keeping') {'back': 1.0}
# ('yes', 'theres') {'something': 1.0}
# ('son', 'you') {'wouldnt': 0.5, 'do': 0.5}
# ('you', 'wouldnt') {'want': 1.0}
# ('wouldnt', 'want') {'to': 1.0}
# ('tell', 'him') {'what': 0.5, 'everything': 0.5}
# ('him', 'what') {'we': 1.0}
# ('we', 'have') {'END': 0.2, 'seen': 0.2, 'ideas': 0.2, 'to': 0.2, 'our': 0.2}
# ('what', 'we') {'have': 0.5, 'ride': 0.5}
# ('attic', 'mother') {'END': 1.0}
# ('mother', 'bones') {'a': 1.0}
# ('a', 'skeleton') {'END': 1.0}
# ('bones', 'a') {'skeleton': 1.0}
# ('son', 'but') {'the': 1.0}
# ('but', 'the') {'headboard': 0.25, 'bones': 0.25, 'pipes': 0.25, 'furniture': 0.25}
# ('the', 'headboard') {'of': 1.0}
# ('headboard', 'of') {'mothers': 0.3333333333333333, 'the': 0.6666666666666666}
# ('of', 'mothers') {'bed': 1.0}
# ('mothers', 'bed') {'is': 1.0}
# ('is', 'pushed') {'END': 1.0}
# ('bed', 'is') {'pushed': 1.0}
# ('attic', 'door') {'the': 1.0}
# ('door', 'the') {'door': 1.0}
# ('is', 'nailed') {'END': 1.0}
# ('door', 'is') {'nailed': 1.0}
# ('its', 'harmless') {'mother': 1.0}
# ('harmless', 'mother') {'hears': 1.0}
# ('mother', 'hears') {'it': 1.0}
# ('hears', 'it') {'in': 1.0}
# ('it', 'in') {'the': 0.5, 'creation': 0.5}
# ('halting', 'perplexed') {'behind': 1.0}
# ('perplexed', 'behind') {'the': 1.0}
# ('the', 'barrier') {'END': 1.0}
# ('of', 'door') {'and': 1.0}
# ('door', 'and') {'headboard': 0.6666666666666666, 'held': 0.3333333333333333}
# ('and', 'headboard') {'where': 0.5, 'of': 0.5}
# ('headboard', 'where') {'it': 1.0}
# ('it', 'wants') {'to': 1.0}
# ('to', 'get') {'END': 0.25, 'to': 0.125, 'outdoors': 0.125, 'out': 0.125, 'at': 0.125, 'married': 0.125, 'away': 0.125}
# ('wants', 'to') {'get': 0.5, 'hear': 0.5}
# ('is', 'back') {'into': 1.0}
# ('back', 'into') {'the': 1.0}
# ('the', 'cellar') {'where': 0.06666666666666667, 'forty': 0.06666666666666667, 'to': 0.06666666666666667, 'END': 0.3333333333333333, 'in': 0.06666666666666667, 'windows': 0.06666666666666667, 'or': 0.06666666666666667, 'bones': 0.06666666666666667, 'wall': 0.06666666666666667, 'after': 0.06666666666666667, 'charred': 0.06666666666666667}
# ('cellar', 'where') {'it': 1.0}
# ('came', 'from') {'END': 1.0}
# ('it', 'came') {'from': 1.0}
# ('mother', 'well') {'never': 1.0}
# ('well', 'never') {'let': 1.0}
# ('let', 'them') {'will': 0.25, 'have': 0.25, 'stay': 0.5}
# ('them', 'will') {'we': 1.0}
# ('will', 'we') {'son': 0.5, 'come': 0.5}
# ('son', 'well') {'END': 1.0}
# ('we', 'son') {'well': 1.0}
# ('son', 'it') {'left': 1.0}
# ('it', 'left') {'the': 1.0}
# ('cellar', 'forty') {'years': 1.0}
# ('years', 'ago') {'END': 1.0}
# ('and', 'carried') {'itself': 1.0}
# ('carried', 'itself') {'like': 1.0}
# ('itself', 'like') {'a': 1.0}
# ('a', 'pile') {'of': 1.0}
# ('of', 'dishes') {'END': 1.0}
# ('pile', 'of') {'dishes': 1.0}
# ('up', 'one') {'flight': 0.5, 'of': 0.5}
# ('one', 'flight') {'from': 1.0}
# ('flight', 'from') {'the': 1.0}
# ('cellar', 'to') {'the': 1.0}
# ('the', 'kitchen') {'END': 0.16666666666666666, 'to': 0.3333333333333333, 'had': 0.16666666666666666, 'chimney': 0.16666666666666666, 'door': 0.16666666666666666}
# ('another', 'from') {'the': 1.0}
# ('kitchen', 'to') {'the': 0.5, 'yourself': 0.5}
# ('the', 'bedroom') {'END': 0.5, 'to': 0.25, 'door': 0.25}
# ('bedroom', 'to') {'the': 1.0}
# ('right', 'past') {'both': 1.0}
# ('past', 'both') {'father': 1.0}
# ('both', 'father') {'and': 1.0}
# ('father', 'and') {'mother': 1.0}
# ('and', 'mother') {'and': 1.0}
# ('neither', 'stopped') {'END': 1.0}
# ('and', 'neither') {'stopped': 1.0}
# ('father', 'had') {'gone': 1.0}
# ('had', 'gone') {'upstairs': 0.5, 'to': 0.5}
# ('gone', 'upstairs') {'mother': 1.0}
# ('upstairs', 'mother') {'was': 1.0}
# ('was', 'downstairs') {'END': 1.0}
# ('mother', 'was') {'downstairs': 0.3333333333333333, 'a': 0.6666666666666666}
# ('a', 'baby') {'i': 1.0}
# ('baby', 'i') {'dont': 1.0}
# ('dont', 'know') {'where': 0.5, 'it': 0.16666666666666666, 'what': 0.16666666666666666, 'END': 0.16666666666666666}
# ('know', 'where') {'i': 0.3333333333333333, 'myself': 0.3333333333333333, 'she': 0.3333333333333333}
# ('mother', 'the') {'only': 1.0}
# ('only', 'fault') {'my': 1.0}
# ('fault', 'my') {'husband': 1.0}
# ('my', 'husband') {'found': 1.0}
# ('husband', 'found') {'with': 1.0}
# ('found', 'with') {'me': 1.0}
# ('i', 'went') {'to': 0.6666666666666666, 'till': 0.3333333333333333}
# ('went', 'to') {'sleep': 0.5, 'bed': 0.5}
# ('to', 'sleep') {'before': 1.0}
# ('sleep', 'before') {'i': 1.0}
# ('to', 'bed') {'END': 0.5, 'alone': 0.5}
# ('especially', 'in') {'winter': 1.0}
# ('winter', 'when') {'the': 1.0}
# ('the', 'bed') {'END': 0.6666666666666666, 'against': 0.3333333333333333}
# ('might', 'just') {'as': 1.0}
# ('well', 'be') {'ice': 1.0}
# ('be', 'ice') {'and': 1.0}
# ('ice', 'and') {'the': 1.0}
# ('clothes', 'snow') {'END': 1.0}
# ('the', 'clothes') {'snow': 1.0}
# ('night', 'the') {'bones': 1.0}
# ('the', 'bones') {'came': 0.2, 'i': 0.2, 'didnt': 0.2, 'END': 0.2, 'liked': 0.2}
# ('bones', 'came') {'up': 1.0}
# ('came', 'up') {'the': 1.0}
# ('the', 'cellarstairs') {'END': 1.0}
# ('toffile', 'had') {'gone': 1.0}
# ('gone', 'to') {'bed': 0.3333333333333333, 'yours': 0.3333333333333333, 'garlands': 0.3333333333333333}
# ('bed', 'alone') {'and': 1.0}
# ('alone', 'and') {'left': 1.0}
# ('left', 'me') {'END': 1.0}
# ('but', 'left') {'an': 1.0}
# ('left', 'an') {'open': 1.0}
# ('an', 'open') {'door': 1.0}
# ('open', 'door') {'to': 0.5, 'up': 0.25, 'END': 0.25}
# ('door', 'to') {'cool': 0.25, 'the': 0.25, 'try': 0.25, 'get': 0.25}
# ('to', 'cool') {'the': 1.0}
# ('cool', 'the') {'room': 0.5, 'eyes': 0.5}
# ('room', 'off') {'END': 1.0}
# ('the', 'room') {'off': 0.3333333333333333, 'though': 0.3333333333333333, 'END': 0.3333333333333333}
# ('so', 'as') {'to': 1.0}
# ('as', 'to') {'sort': 0.3333333333333333, 'have': 0.3333333333333333, 'hens': 0.3333333333333333}
# ('to', 'sort') {'of': 1.0}
# ('of', 'turn') {'me': 1.0}
# ('turn', 'me') {'out': 1.0}
# ('me', 'out') {'of': 1.0}
# ('was', 'just') {'coming': 1.0}
# ('just', 'coming') {'to': 1.0}
# ('coming', 'to') {'myself': 1.0}
# ('myself', 'enough') {'END': 1.0}
# ('to', 'myself') {'enough': 1.0}
# ('to', 'wonder') {'where': 1.0}
# ('wonder', 'where') {'the': 0.5, 'your': 0.5}
# ('cold', 'was') {'coming': 1.0}
# ('coming', 'from') {'END': 1.0}
# ('was', 'coming') {'from': 0.5, 'up': 0.5}
# ('i', 'heard') {'toffile': 0.3333333333333333, 'him': 0.3333333333333333, 'them': 0.3333333333333333}
# ('heard', 'toffile') {'upstairs': 1.0}
# ('toffile', 'upstairs') {'in': 1.0}
# ('upstairs', 'in') {'the': 1.0}
# ('and', 'thought') {'i': 1.0}
# ('thought', 'i') {'heard': 0.3333333333333333, 'saw': 0.3333333333333333, 'had': 0.3333333333333333}
# ('heard', 'him') {'downstairs': 1.0}
# ('him', 'downstairs') {'in': 1.0}
# ('downstairs', 'in') {'the': 1.0}
# ('the', 'board') {'we': 0.5, 'END': 0.5}
# ('board', 'we') {'had': 1.0}
# ('we', 'had') {'laid': 1.0}
# ('had', 'laid') {'down': 1.0}
# ('laid', 'down') {'to': 1.0}
# ('to', 'walk') {'dryshod': 1.0}
# ('dryshod', 'on') {'END': 1.0}
# ('walk', 'dryshod') {'on': 1.0}
# ('when', 'there') {'was': 1.0}
# ('was', 'water') {'in': 1.0}
# ('water', 'in') {'the': 1.0}
# ('in', 'spring') {'END': 1.0}
# ('cellar', 'in') {'spring': 1.0}
# ('struck', 'the') {'hard': 0.5, 'hand': 0.5}
# ('the', 'hard') {'cellar': 1.0}
# ('hard', 'cellar') {'bottom': 1.0}
# ('cellar', 'bottom') {'and': 1.0}
# ('bottom', 'and') {'then': 1.0}
# ('then', 'someone') {'END': 1.0}
# ('began', 'the') {'stairs': 1.0}
# ('the', 'stairs') {'two': 0.3333333333333333, 'END': 0.3333333333333333, 'at': 0.3333333333333333}
# ('stairs', 'two') {'footsteps': 1.0}
# ('two', 'footsteps') {'for': 1.0}
# ('footsteps', 'for') {'each': 1.0}
# ('each', 'step') {'END': 1.0}
# ('for', 'each') {'step': 0.5, 'branch': 0.5}
# ('way', 'a') {'man': 1.0}
# ('a', 'man') {'with': 0.16666666666666666, 'but': 0.16666666666666666, 'he': 0.16666666666666666, 'let': 0.16666666666666666, 'to': 0.16666666666666666, 'at': 0.16666666666666666}
# ('man', 'with') {'one': 1.0}
# ('with', 'one') {'leg': 0.5, 'hand': 0.5}
# ('one', 'leg') {'and': 1.0}
# ('leg', 'and') {'a': 1.0}
# ('a', 'crutch') {'END': 1.0}
# ('or', 'a') {'little': 0.3333333333333333, 'scribble': 0.3333333333333333, 'pound': 0.3333333333333333}
# ('a', 'little') {'child': 0.2, 'little': 0.2, 'longer': 0.2, 'finger': 0.2, 'yesterday': 0.2}
# ('little', 'child') {'comes': 1.0}
# ('child', 'comes') {'up': 1.0}
# ('comes', 'up') {'it': 1.0}
# ('up', 'it') {'wasnt': 1.0}
# ('wasnt', 'toffile') {'END': 1.0}
# ('it', 'wasnt') {'toffile': 0.5, 'anyone': 0.5}
# ('wasnt', 'anyone') {'who': 1.0}
# ('anyone', 'who') {'could': 1.0}
# ('who', 'could') {'be': 1.0}
# ('be', 'there') {'END': 1.0}
# ('could', 'be') {'there': 1.0}
# ('the', 'bulkhead') {'doubledoors': 1.0}
# ('bulkhead', 'doubledoors') {'were': 1.0}
# ('were', 'doublelocked') {'END': 1.0}
# ('doubledoors', 'were') {'doublelocked': 1.0}
# ('swollen', 'tight') {'and': 1.0}
# ('tight', 'and') {'buried': 1.0}
# ('and', 'buried') {'under': 1.0}
# ('under', 'snow') {'END': 1.0}
# ('buried', 'under') {'snow': 1.0}
# ('cellar', 'windows') {'were': 1.0}
# ('windows', 'were') {'banked': 1.0}
# ('were', 'banked') {'up': 1.0}
# ('banked', 'up') {'with': 1.0}
# ('with', 'sawdust') {'END': 1.0}
# ('bones', 'i') {'knew': 1.0}
# ('knew', 'them') {'and': 1.0}
# ('them', 'and') {'good': 1.0}
# ('good', 'reason') {'END': 1.0}
# ('and', 'good') {'reason': 1.0}
# ('my', 'first') {'impulse': 1.0}
# ('first', 'impulse') {'was': 1.0}
# ('impulse', 'was') {'to': 1.0}
# ('get', 'to') {'the': 1.0}
# ('the', 'knob') {'END': 1.0}
# ('door', 'but') {'the': 1.0}
# ('didnt', 'try') {'END': 1.0}
# ('bones', 'didnt') {'try': 1.0}
# ('door', 'they') {'halted': 1.0}
# ('they', 'halted') {'helpless': 1.0}
# ('halted', 'helpless') {'on': 1.0}
# ('helpless', 'on') {'the': 1.0}
# ('the', 'landing') {'END': 1.0}
# ('for', 'things') {'to': 1.0}
# ('to', 'happen') {'in': 1.0}
# ('happen', 'in') {'their': 1.0}
# ('their', 'favour') {'END': 1.0}
# ('the', 'faintest') {'restless': 1.0}
# ('faintest', 'restless') {'rustling': 1.0}
# ('restless', 'rustling') {'ran': 1.0}
# ('rustling', 'ran') {'all': 1.0}
# ('ran', 'all') {'through': 1.0}
# ('through', 'them') {'END': 1.0}
# ('all', 'through') {'them': 1.0}
# ('never', 'could') {'have': 0.5, 'find': 0.5}
# ('have', 'done') {'the': 1.0}
# ('done', 'the') {'thing': 1.0}
# ('the', 'thing') {'i': 0.5, 'from': 0.5}
# ('i', 'did') {'END': 1.0}
# ('thing', 'i') {'did': 1.0}
# ('the', 'wish') {'hadnt': 1.0}
# ('wish', 'hadnt') {'been': 1.0}
# ('hadnt', 'been') {'too': 1.0}
# ('too', 'strong') {'in': 1.0}
# ('in', 'me') {'END': 1.0}
# ('strong', 'in') {'me': 1.0}
# ('see', 'how') {'they': 0.5, 'wet': 0.5}
# ('how', 'they') {'were': 1.0}
# ('were', 'mounted') {'for': 1.0}
# ('mounted', 'for') {'this': 1.0}
# ('this', 'walk') {'END': 1.0}
# ('i', 'had') {'a': 0.2, 'just': 0.1, 'to': 0.2, 'for': 0.1, 'the': 0.3, 'such': 0.1}
# ('had', 'a') {'vision': 0.2, 'grave': 0.4, 'myth': 0.2, 'glimpse': 0.2}
# ('a', 'vision') {'of': 1.0}
# ('vision', 'of') {'them': 1.0}
# ('put', 'together') {'END': 1.0}
# ('them', 'put') {'together': 1.0}
# ('not', 'like') {'a': 1.0}
# ('man', 'but') {'like': 1.0}
# ('but', 'like') {'a': 1.0}
# ('a', 'chandelier') {'END': 1.0}
# ('so', 'suddenly') {'i': 1.0}
# ('suddenly', 'i') {'flung': 1.0}
# ('i', 'flung') {'the': 1.0}
# ('flung', 'the') {'door': 1.0}
# ('door', 'wide') {'on': 0.5, 'but': 0.5}
# ('wide', 'on') {'him': 1.0}
# ('a', 'moment') {'he': 1.0}
# ('moment', 'he') {'stood': 0.5, 'was': 0.5}
# ('stood', 'balancing') {'with': 1.0}
# ('with', 'emotion') {'END': 1.0}
# ('balancing', 'with') {'emotion': 1.0}
# ('and', 'all') {'but': 0.3333333333333333, 'our': 0.3333333333333333, 'END': 0.3333333333333333}
# ('all', 'but') {'lost': 0.5, 'me': 0.5}
# ('but', 'lost') {'himself': 1.0}
# ('lost', 'himself') {'a': 1.0}
# ('himself', 'a') {'tongue': 1.0}
# ('a', 'tongue') {'of': 1.0}
# ('of', 'fire') {'END': 0.6666666666666666, 'drowned': 0.3333333333333333}
# ('tongue', 'of') {'fire': 1.0}
# ('flashed', 'out') {'and': 1.0}
# ('and', 'licked') {'along': 1.0}
# ('licked', 'along') {'his': 1.0}
# ('along', 'his') {'upper': 1.0}
# ('upper', 'teeth') {'END': 1.0}
# ('his', 'upper') {'teeth': 1.0}
# ('smoke', 'rolled') {'inside': 1.0}
# ('rolled', 'inside') {'the': 1.0}
# ('inside', 'the') {'sockets': 1.0}
# ('the', 'sockets') {'of': 1.0}
# ('sockets', 'of') {'his': 1.0}
# ('then', 'he') {'came': 0.5, 'cant': 0.5}
# ('came', 'at') {'me': 1.0}
# ('at', 'me') {'with': 1.0}
# ('me', 'with') {'one': 1.0}
# ('hand', 'outstretched') {'END': 1.0}
# ('one', 'hand') {'outstretched': 1.0}
# ('did', 'in') {'life': 1.0}
# ('in', 'life') {'once': 1.0}
# ('life', 'once') {'but': 1.0}
# ('once', 'but') {'this': 1.0}
# ('this', 'time') {'END': 1.0}
# ('but', 'this') {'time': 1.0}
# ('i', 'struck') {'the': 1.0}
# ('the', 'hand') {'off': 1.0}
# ('hand', 'off') {'brittle': 1.0}
# ('off', 'brittle') {'on': 1.0}
# ('brittle', 'on') {'the': 1.0}
# ('and', 'fell') {'back': 1.0}
# ('fell', 'back') {'from': 1.0}
# ('from', 'him') {'on': 0.3333333333333333, 'END': 0.3333333333333333, 'thats': 0.3333333333333333}
# ('him', 'on') {'the': 1.0}
# ('floor', 'myself') {'END': 1.0}
# ('the', 'fingerpieces') {'slid': 1.0}
# ('fingerpieces', 'slid') {'in': 1.0}
# ('slid', 'in') {'all': 1.0}
# ('all', 'directions') {'END': 1.0}
# ('in', 'all') {'directions': 1.0}
# ('where', 'did') {'i': 1.0}
# ('did', 'i') {'see': 1.0}
# ('i', 'see') {'one': 0.25, 'END': 0.25, 'raspberry': 0.25, 'its': 0.25}
# ('see', 'one') {'of': 1.0}
# ('of', 'those') {'pieces': 1.0}
# ('pieces', 'lately') {'END': 1.0}
# ('those', 'pieces') {'lately': 1.0}
# ('hand', 'me') {'my': 1.0}
# ('me', 'my') {'buttonbox': 1.0}
# ('my', 'buttonbox') {'it': 1.0}
# ('buttonbox', 'it') {'must': 1.0}
# ('i', 'sat') {'up': 1.0}
# ('sat', 'up') {'on': 1.0}
# ('up', 'on') {'the': 1.0}
# ('floor', 'and') {'shouted': 1.0}
# ('shouted', 'toffile') {'END': 1.0}
# ('and', 'shouted') {'toffile': 0.5, 'shut': 0.5}
# ('its', 'coming') {'up': 1.0}
# ('coming', 'up') {'to': 0.5, 'had': 0.5}
# ('you', 'it') {'had': 0.5, 'isnt': 0.5}
# ('its', 'choice') {'END': 1.0}
# ('had', 'its') {'choice': 1.0}
# ('cellar', 'or') {'the': 1.0}
# ('the', 'hall') {'END': 0.3333333333333333, 'door': 0.3333333333333333, 'to': 0.3333333333333333}
# ('or', 'the') {'hall': 1.0}
# ('it', 'took') {'the': 1.0}
# ('hall', 'door') {'for': 1.0}
# ('door', 'for') {'the': 1.0}
# ('the', 'novelty') {'END': 1.0}
# ('and', 'set') {'off': 1.0}
# ('set', 'off') {'briskly': 1.0}
# ('off', 'briskly') {'for': 1.0}
# ('briskly', 'for') {'so': 1.0}
# ('for', 'so') {'slow': 1.0}
# ('so', 'slow') {'a': 1.0}
# ('a', 'thing') {'END': 1.0}
# ('slow', 'a') {'thing': 1.0}
# ('stillgoing', 'every') {'which': 1.0}
# ('every', 'which') {'way': 1.0}
# ('which', 'way') {'in': 1.0}
# ('way', 'in') {'the': 1.0}
# ('joints', 'though') {'END': 1.0}
# ('the', 'joints') {'though': 1.0}
# ('so', 'that') {'it': 0.3333333333333333, 'ought': 0.3333333333333333, 'was': 0.3333333333333333}
# ('that', 'it') {'looked': 1.0}
# ...
# ('how', 'many') {'times': 1.0}
# ('mean', 'thats') {'johns': 1.0}
# ('johns', 'idea') {'END': 1.0}
# ('thats', 'johns') {'idea': 1.0}
# ('and', 'we') {'live': 0.5, 'paid': 0.5}
# ('we', 'live') {'up': 1.0}
# ('live', 'up') {'to': 1.0}
# ('to', 'it') {'or': 0.5, 'and': 0.5}
# ('what', 'childishness') {'he': 1.0}
# ('childishness', 'he') {'wouldnt': 1.0}
# ('he', 'wouldnt') {'give': 1.0}
# ('wouldnt', 'give') {'way': 1.0}
# ('give', 'way') {'to': 1.0}
# ('he', 'manages') {'to': 1.0}
# ('manages', 'to') {'keep': 1.0}
# ('upper', 'hand') {'END': 1.0}
# ('the', 'upper') {'hand': 0.5, 'shelf': 0.5}
# ('own', 'farm') {'hes': 1.0}
# ('farm', 'hes') {'boss': 1.0}
# ('hes', 'boss') {'but': 1.0}
# ('boss', 'but') {'as': 1.0}
# ('but', 'as') {'to': 1.0}
# ('to', 'hens') {'END': 1.0}
# ('we', 'fence') {'our': 1.0}
# ('fence', 'our') {'flowers': 1.0}
# ('our', 'flowers') {'in': 1.0}
# ('hens', 'range') {'END': 1.0}
# ('the', 'hens') {'range': 1.0}
# ('nothings', 'too') {'good': 1.0}
# ('too', 'good') {'for': 1.0}
# ('them', 'we') {'say': 1.0}
# ('it', 'pays') {'END': 1.0}
# ('john', 'likes') {'to': 1.0}
# ('likes', 'to') {'tell': 1.0}
# ('the', 'offers') {'he': 1.0}
# ('offers', 'he') {'has': 1.0}
# ('has', 'had') {'END': 1.0}
# ('twenty', 'for') {'this': 1.0}
# ('this', 'cock') {'twentyfive': 1.0}
# ('cock', 'twentyfive') {'for': 1.0}
# ('twentyfive', 'for') {'that': 1.0}
# ('never', 'takes') {'the': 1.0}
# ('the', 'money') {'if': 0.5, 'goes': 0.5}
# ('money', 'if') {'theyre': 1.0}
# ('theyre', 'worth') {'END': 0.5, 'as': 0.5}
# ('if', 'theyre') {'worth': 1.0}
# ('that', 'much') {'to': 1.0}
# ('sell', 'theyre') {'worth': 1.0}
# ('worth', 'as') {'much': 1.0}
# ('as', 'much') {'to': 1.0}
# ('you', 'its') {'all': 1.0}
# ('its', 'all') {'expense': 0.5, 'up': 0.5}
# ('all', 'expense') {'though': 1.0}
# ('expense', 'though') {'reach': 1.0}
# ('though', 'reach') {'me': 1.0}
# ('me', 'down') {'END': 1.0}
# ('reach', 'me') {'down': 1.0}
# ('little', 'tin') {'box': 1.0}
# ('tin', 'box') {'on': 0.5, 'thats': 0.5}
# ('box', 'on') {'the': 1.0}
# ('cupboard', 'shelf') {'END': 1.0}
# ('the', 'cupboard') {'shelf': 1.0}
# ('upper', 'shelf') {'the': 1.0}
# ('shelf', 'the') {'tin': 1.0}
# ('the', 'tin') {'box': 1.0}
# ('box', 'thats') {'the': 1.0}
# ('thats', 'the') {'one': 1.0}
# ('whats', 'this') {'END': 1.0}
# ('a', 'bill') {'END': 1.0}
# ('for', 'fifty') {'dollars': 1.0}
# ('fifty', 'dollars') {'for': 1.0}
# ('dollars', 'for') {'one': 1.0}
# ('for', 'one') {'langshang': 1.0}
# ('langshang', 'cock') {'END': 1.0}
# ('one', 'langshang') {'cock': 1.0}
# ('receipted', 'and') {'the': 1.0}
# ('the', 'cock') {'is': 1.0}
# ('cock', 'is') {'in': 1.0}
# ('a', 'glass') {'case': 1.0}
# ('case', 'then') {'END': 1.0}
# ('glass', 'case') {'then': 0.5, 'as': 0.5}
# ('hed', 'need') {'a': 1.0}
# ('need', 'a') {'tall': 1.0}
# ('tall', 'one') {'END': 1.0}
# ('a', 'tall') {'one': 1.0}
# ('he', 'can') {'eat': 0.5, 'stretch': 0.5}
# ('can', 'eat') {'off': 1.0}
# ('eat', 'off') {'a': 1.0}
# ('off', 'a') {'barrel': 1.0}
# ('a', 'barrel') {'from': 1.0}
# ('barrel', 'from') {'the': 1.0}
# ('hes', 'been') {'in': 1.0}
# ('been', 'in') {'a': 1.0}
# ('case', 'as') {'you': 1.0}
# ('the', 'crystal') {'palace': 1.0}
# ('crystal', 'palace') {'london': 1.0}
# ('palace', 'london') {'hes': 1.0}
# ('hes', 'imported') {'END': 1.0}
# ('london', 'hes') {'imported': 1.0}
# ('john', 'bought') {'him': 1.0}
# ('bought', 'him') {'and': 1.0}
# ('him', 'and') {'we': 0.5, 'stop': 0.5}
# ('we', 'paid') {'the': 1.0}
# ('paid', 'the') {'bill': 1.0}
# ('the', 'bill') {'with': 1.0}
# ('with', 'beads') {'END': 1.0}
# ('bill', 'with') {'beads': 1.0}
# ('wampum', 'i') {'call': 1.0}
# ('i', 'call') {'it': 1.0}
# ('it', 'mind') {'we': 1.0}
# ('mind', 'we') {'dont': 1.0}
# ('we', 'dont') {'complain': 1.0}
# ('see', 'dont') {'you': 1.0}
# ('you', 'we') {'take': 1.0}
# ('we', 'take') {'care': 1.0}
# ('take', 'care') {'of': 1.0}
# ('care', 'of') {'him': 1.0}
# ('and', 'like') {'it': 1.0}
# ('like', 'it') {'too': 1.0}
# ('too', 'it') {'makes': 1.0}
# ('it', 'makes') {'it': 1.0}
# ('makes', 'it') {'all': 1.0}
# ('the', 'worse') {'END': 0.5, 'you': 0.5}
# ('seems', 'as') {'if': 1.0}
# ('if', 'and') {'thats': 1.0}
# ('thats', 'not') {'all': 1.0}
# ('hes', 'helpless') {'END': 1.0}
# ('all', 'hes') {'helpless': 1.0}
# ('in', 'ways') {'that': 1.0}
# ('ways', 'that') {'i': 1.0}
# ('can', 'hardly') {'tell': 1.0}
# ('hardly', 'tell') {'you': 1.0}
# ('you', 'of') {'END': 1.0}
# ('gets', 'possessed') {'to': 1.0}
# ('possessed', 'to') {'keep': 1.0}
# ('keep', 'accounts') {'END': 1.0}
# ('see', 'where') {'all': 1.0}
# ('where', 'all') {'the': 1.0}
# ('money', 'goes') {'so': 1.0}
# ('so', 'fast') {'END': 1.0}
# ('goes', 'so') {'fast': 1.0}
# ('know', 'how') {'men': 1.0}
# ('how', 'men') {'will': 1.0}
# ('men', 'will') {'be': 1.0}
# ('be', 'ridiculous') {'END': 1.0}
# ('but', 'its') {'just': 1.0}
# ('its', 'just') {'fun': 1.0}
# ('just', 'fun') {'the': 1.0}
# ('fun', 'the') {'way': 1.0}
# ('gets', 'bedeviled') {'END': 1.0}
# ('hes', 'untidy') {'now': 1.0}
# ('untidy', 'now') {'what': 1.0}
# ('now', 'what') {'will': 1.0}
# ('he', 'be') {'END': 1.0}
# ('worse', 'you') {'must': 1.0}
# ('be', 'blind') {'END': 1.0}
# ('estelles', 'the') {'one': 1.0}
# ('one', 'you') {'neednt': 1.0}
# ('you', 'neednt') {'talk': 0.5, 'think': 0.5}
# ('neednt', 'talk') {'to': 1.0}
# ('cant', 'you') {'and': 1.0}
# ('i', 'get') {'to': 1.0}
# ('the', 'root') {'of': 1.0}
# ('root', 'of') {'it': 1.0}
# ('the', 'real') {'trouble': 1.0}
# ('real', 'trouble') {'what': 1.0}
# ('trouble', 'what') {'will': 1.0}
# ('satisfy', 'her') {'END': 1.0}
# ('will', 'satisfy') {'her': 1.0}
# ('say', 'shes') {'turned': 1.0}
# ('shes', 'turned') {'from': 1.0}
# ('turned', 'from') {'him': 1.0}
# ('thats', 'all') {'END': 1.0}
# ('him', 'thats') {'all': 1.0}
# ('why', 'when') {'shes': 1.0}
# ('shes', 'well') {'off': 1.0}
# ('off', 'is') {'it': 1.0}
# ('the', 'neighbours') {'END': 1.0}
# ('it', 'the') {'neighbours': 1.0}
# ('being', 'cut') {'off': 1.0}
# ('cut', 'off') {'from': 1.0}
# ('from', 'friends') {'END': 1.0}
# ('our', 'friends') {'END': 1.0}
# ('have', 'our') {'friends': 1.0}
# ('that', 'isnt') {'it': 1.0}
# ('isnt', 'it') {'folks': 0.5, 'hell': 0.5}
# ('it', 'folks') {'arent': 1.0}
# ('folks', 'arent') {'afraid': 1.0}
# ('arent', 'afraid') {'of': 1.0}
# ('shes', 'let') {'it': 1.0}
# ('let', 'it') {'worry': 1.0}
# ('it', 'worry') {'her': 1.0}
# ('worry', 'her') {'you': 1.0}
# ('her', 'you') {'stood': 1.0}
# ('you', 'stood') {'the': 1.0}
# ('the', 'strain') {'END': 1.0}
# ('stood', 'the') {'strain': 1.0}
# ('and', 'youre') {'her': 1.0}
# ('youre', 'her') {'mother': 1.0}
# ('didnt', 'always') {'END': 1.0}
# ('didnt', 'relish') {'it': 1.0}
# ('relish', 'it') {'along': 1.0}
# ('it', 'along') {'at': 1.0}
# ('at', 'first') {'END': 1.0}
# ('along', 'at') {'first': 1.0}
# ('got', 'wonted') {'to': 1.0}
# ('wonted', 'to') {'it': 1.0}
# ('john', 'said') {'i': 1.0}
# ('was', 'too') {'old': 1.0}
# ('old', 'to') {'have': 1.0}
# ('have', 'grandchildren') {'END': 1.0}
# ('but', 'whats') {'the': 1.0}
# ('of', 'talking') {'when': 1.0}
# ('talking', 'when') {'its': 1.0}
# ('when', 'its') {'done': 1.0}
# ('back', 'its') {'worse': 1.0}
# ('its', 'worse') {'than': 1.0}
# ('worse', 'than') {'that': 1.0}
# ('she', 'cant') {'END': 1.0}
# ('that', 'she') {'cant': 1.0}
# ('why', 'do') {'you': 1.0}
# ('you', 'speak') {'like': 1.0}
# ('speak', 'like') {'that': 1.0}
# ('mean', 'shes') {'done': 0.5, 'married': 0.5}
# ('shes', 'done') {'harm': 1.0}
# ('done', 'harm') {'to': 1.0}
# ('harm', 'to') {'herself': 1.0}
# ('shes', 'married') {'married': 1.0}
# ('married', 'married') {'someone': 1.0}
# ('someone', 'else') {'END': 1.0}
# ('married', 'someone') {'else': 1.0}
# ('oho', 'oho') {'END': 1.0}
# ('believe', 'me') {'END': 1.0}
# ('yes', 'i') {'do': 1.0}
# ('only', 'too') {'well': 1.0}
# ('too', 'well') {'i': 1.0}
# ('knew', 'there') {'must': 1.0}
# ('there', 'must') {'be': 1.0}
# ('be', 'something') {'END': 1.0}
# ('was', 'what') {'was': 1.0}
# ('was', 'back') {'shes': 1.0}
# ('shes', 'bad') {'thats': 1.0}
# ('bad', 'thats') {'all': 1.0}
# ('get', 'married') {'when': 1.0}
# ('married', 'when') {'she': 1.0}
# ('when', 'she') {'had': 1.0}
# ('nonsense', 'see') {'whats': 1.0}
# ('see', 'whats') {'she': 1.0}
# ('whats', 'she') {'done': 1.0}
# ('she', 'done') {'but': 1.0}
# ('done', 'but') {'who': 1.0}
# ('who', 'who') {'END': 1.0}
# ('but', 'who') {'who': 1.0}
# ('whod', 'marry') {'her': 1.0}
# ('her', 'straight') {'out': 1.0}
# ('straight', 'out') {'of': 1.0}
# ('of', 'such') {'a': 1.0}
# ('a', 'mess') {'END': 1.0}
# ('right', 'out') {'no': 1.0}
# ('out', 'no') {'matter': 1.0}
# ('the', 'man') {'was': 0.5, 'im': 0.5}
# ('man', 'was') {'found': 1.0}
# ('was', 'found') {'id': 1.0}
# ('found', 'id') {'better': 1.0}
# ('id', 'better') {'name': 1.0}
# ('better', 'name') {'no': 1.0}
# ('name', 'no') {'names': 1.0}
# ('john', 'himself') {'wont': 1.0}
# ('himself', 'wont') {'imagine': 1.0}
# ('wont', 'imagine') {'who': 1.0}
# ('imagine', 'who') {'he': 1.0}
# ('all', 'up') {'i': 1.0}
# ('up', 'i') {'think': 1.0}
# ('think', 'ill') {'get': 1.0}
# ('get', 'away') {'END': 1.0}
# ('ill', 'get') {'away': 1.0}
# ('youll', 'be') {'expecting': 1.0}
# ('be', 'expecting') {'john': 1.0}
# ('expecting', 'john') {'i': 1.0}
# ('john', 'i') {'pity': 1.0}
# ('pity', 'estelle') {'END': 1.0}
# ('i', 'pity') {'estelle': 1.0}
# ('i', 'suppose') {'she': 1.0}
# ('suppose', 'she') {'deserves': 1.0}
# ('she', 'deserves') {'some': 1.0}
# ('deserves', 'some') {'pity': 1.0}
# ('pity', 'too') {'END': 1.0}
# ('some', 'pity') {'too': 1.0}
# ('to', 'yourself') {'END': 1.0}
# ('to', 'break') {'it': 1.0}
# ('break', 'it') {'to': 1.0}
# ('him', 'you') {'may': 1.0}
# ('the', 'job') {'END': 1.0}
# ('neednt', 'think') {'youre': 1.0}
# ('johns', 'almost') {'here': 1.0}
# ('almost', 'here') {'ive': 1.0}
# ('here', 'ive') {'had': 1.0}
# ('ive', 'had') {'my': 1.0}
# ('had', 'my') {'eye': 1.0}
# ('my', 'eye') {'on': 1.0}
# ('on', 'someone') {'END': 1.0}
# ('eye', 'on') {'someone': 1.0}
# ('coming', 'down') {'ryans': 1.0}
# ('down', 'ryans') {'hill': 1.0}
# ('ryans', 'hill') {'i': 1.0}
# ('hill', 'i') {'thought': 1.0}
# ('twas', 'him') {'END': 1.0}
# ('thought', 'twas') {'him': 1.0}
# ('here', 'he') {'is': 1.0}
# ('is', 'now') {'this': 1.0}
# ('now', 'this') {'box': 1.0}
# ('this', 'box') {'put': 1.0}
# ('box', 'put') {'it': 1.0}
# ('it', 'away') {'END': 1.0}
# ('put', 'it') {'away': 1.0}
# ('this', 'bill') {'END': 1.0}
# ('the', 'hurry') {'hell': 1.0}
# ('hell', 'unhitch') {'END': 1.0}
# ('hurry', 'hell') {'unhitch': 1.0}
# ('no', 'he') {'wont': 1.0}
# ('wont', 'either') {'hell': 1.0}
# ('either', 'hell') {'just': 1.0}
# ('hell', 'just') {'drop': 1.0}
# ('just', 'drop') {'the': 1.0}
# ('the', 'reins') {'END': 1.0}
# ('drop', 'the') {'reins': 1.0}
# ('and', 'turn') {'doll': 1.0}
# ('turn', 'doll') {'out': 1.0}
# ('doll', 'out') {'to': 1.0}
# ('to', 'pasture') {'rig': 1.0}
# ('pasture', 'rig') {'and': 1.0}
# ('rig', 'and') {'all': 1.0}
# ('wont', 'get') {'far': 1.0}
# ('get', 'far') {'before': 1.0}
# ('far', 'before') {'the': 1.0}
# ('the', 'wheels') {'hang': 1.0}
# ('hang', 'up') {'END': 1.0}
# ('wheels', 'hang') {'up': 1.0}
# ('on', 'something') {'theres': 1.0}
# ('something', 'theres') {'no': 1.0}
# ('theres', 'no') {'harm': 1.0}
# ('no', 'harm') {'see': 1.0}
# ('harm', 'see') {'there': 1.0}
# ('see', 'there') {'he': 1.0}
# ('there', 'he') {'is': 1.0}
# ('my', 'but') {'he': 1.0}
# ('he', 'looks') {'as': 1.0}
# ('john', 'threw') {'the': 1.0}
# ('threw', 'the') {'door': 1.0}
# ('wide', 'but') {'he': 1.0}
# ('didnt', 'enter') {'END': 1.0}
# ('he', 'didnt') {'enter': 1.0}
# ('how', 'are') {'you': 1.0}
# ('are', 'you') {'neighbour': 1.0}
# ('you', 'neighbour') {'just': 1.0}
# ('neighbour', 'just') {'the': 1.0}
# ('im', 'after') {'END': 1.0}
# ('man', 'im') {'after': 1.0}
# ('it', 'hell') {'he': 1.0}
# ('hell', 'he') {'said': 1.0}
# ('come', 'out') {'here': 0.5, 'to': 0.5}
# ('here', 'if') {'you': 1.0}
# ('me', 'talk') {'END': 1.0}
# ('hear', 'me') {'talk': 1.0}
# ('ill', 'talk') {'to': 1.0}
# ('you', 'old') {'woman': 1.0}
# ('woman', 'afterward') {'END': 1.0}
# ('old', 'woman') {'afterward': 1.0}
# ('ive', 'got') {'some': 1.0}
# ('got', 'some') {'news': 1.0}
# ('some', 'news') {'that': 1.0}
# ('news', 'that') {'maybe': 1.0}
# ('that', 'maybe') {'isnt': 1.0}
# ('isnt', 'news') {'END': 1.0}
# ('maybe', 'isnt') {'news': 1.0}
# ('what', 'are') {'they': 1.0}
# ('they', 'trying') {'to': 1.0}
# ('trying', 'to') {'do': 1.0}
# ('these', 'two') {'END': 1.0}
# ('me', 'these') {'two': 1.0}
# ('do', 'go') {'along': 1.0}
# ('go', 'along') {'with': 1.0}
# ('along', 'with') {'him': 1.0}
# ('and', 'stop') {'his': 1.0}
# ('his', 'shouting') {'END': 1.0}
# ('stop', 'his') {'shouting': 1.0}
# ('she', 'raised') {'her': 1.0}
# ('raised', 'her') {'voice': 1.0}
# ('her', 'voice') {'against': 1.0}
# ('voice', 'against') {'the': 1.0}
# ('closing', 'door') {'END': 1.0}
# ('the', 'closing') {'door': 1.0}
# ('who', 'wants') {'to': 1.0}
# ('hear', 'your') {'news': 1.0}
# ('your', 'news') {'you': 1.0}
# ('dreadful', 'fool') {'END': 1.0}
# ('you', 'dreadful') {'fool': 1.0}
# ('winter', 'garden') {'in': 1.0}
# ('garden', 'in') {'an': 1.0}
# ('alder', 'swamp') {'END': 1.0}
# ('an', 'alder') {'swamp': 1.0}
# ('where', 'conies') {'now': 1.0}
# ('conies', 'now') {'come': 1.0}
# ('now', 'come') {'out': 1.0}
# ('to', 'sun') {'and': 1.0}
# ('and', 'romp') {'END': 1.0}
# ('sun', 'and') {'romp': 1.0}
# ('as', 'near') {'a': 1.0}
# ('near', 'a') {'paradise': 1.0}
# ('a', 'paradise') {'as': 1.0}
# ('paradise', 'as') {'it': 1.0}
# ('it', 'can') {'be': 1.0}
# ('and', 'not') {'melt': 1.0}
# ('not', 'melt') {'snow': 1.0}
# ('melt', 'snow') {'or': 1.0}
# ('snow', 'or') {'start': 1.0}
# ('or', 'start') {'a': 1.0}
# ('start', 'a') {'dormant': 1.0}
# ('dormant', 'tree') {'END': 1.0}
# ('a', 'dormant') {'tree': 1.0}
# ('it', 'lifts') {'existence': 0.5, 'a': 0.5}
# ('lifts', 'existence') {'on': 1.0}
# ('existence', 'on') {'a': 1.0}
# ('a', 'plane') {'of': 1.0}
# ('plane', 'of') {'snow': 1.0}
# ('one', 'level') {'higher': 0.5, 'nearer': 0.5}
# ('level', 'higher') {'than': 1.0}
# ('higher', 'than') {'the': 1.0}
# ('earth', 'below') {'END': 1.0}
# ('level', 'nearer') {'heaven': 1.0}
# ('heaven', 'overhead') {'END': 1.0}
# ('nearer', 'heaven') {'overhead': 1.0}
# ('and', 'last') {'years': 1.0}
# ('last', 'years') {'berries': 1.0}
# ('years', 'berries') {'shining': 1.0}
# ('berries', 'shining') {'scarlet': 1.0}
# ('scarlet', 'red') {'END': 1.0}
# ('shining', 'scarlet') {'red': 1.0}
# ('lifts', 'a') {'gaunt': 1.0}
# ('a', 'gaunt') {'luxuriating': 1.0}
# ('luxuriating', 'beast') {'END': 1.0}
# ('gaunt', 'luxuriating') {'beast': 1.0}
# ('can', 'stretch') {'and': 1.0}
# ('stretch', 'and') {'hold': 1.0}
# ('hold', 'his') {'highest': 1.0}
# ('highest', 'feat') {'END': 1.0}
# ('his', 'highest') {'feat': 1.0}
# ('on', 'some') {'wild': 1.0}
# ('some', 'wild') {'apple': 1.0}
# ('wild', 'apple') {'trees': 1.0}
# ('trees', 'young') {'tender': 1.0}
# ('tender', 'bark') {'END': 1.0}
# ('young', 'tender') {'bark': 1.0}
# ('what', 'well') {'may': 1.0}
# ('well', 'may') {'prove': 1.0}
# ('may', 'prove') {'the': 1.0}
# ('prove', 'the') {'years': 1.0}
# ('the', 'years') {'high': 1.0}
# ('years', 'high') {'girdle': 1.0}
# ('girdle', 'mark') {'END': 1.0}
# ('high', 'girdle') {'mark': 1.0}
# ('near', 'to') {'paradise': 1.0}
# ('to', 'paradise') {'all': 1.0}
# ('paradise', 'all') {'pairing': 1.0}
# ('pairing', 'ends') {'END': 1.0}
# ('all', 'pairing') {'ends': 1.0}
# ('here', 'loveless') {'birds': 1.0}
# ('loveless', 'birds') {'now': 1.0}
# ('birds', 'now') {'flock': 1.0}
# ('now', 'flock') {'as': 1.0}
# ('flock', 'as') {'winter': 1.0}
# ('winter', 'friends') {'END': 1.0}
# ('as', 'winter') {'friends': 1.0}
# ('content', 'with') {'budinspecting': 1.0}
# ('with', 'budinspecting') {'they': 1.0}
# ('they', 'presume') {'END': 1.0}
# ('budinspecting', 'they') {'presume': 1.0}
# ('say', 'which') {'buds': 1.0}
# ('which', 'buds') {'are': 1.0}
# ('buds', 'are') {'leaf': 1.0}
# ('are', 'leaf') {'and': 1.0}
# ('leaf', 'and') {'which': 1.0}
# ('and', 'which') {'are': 1.0}
# ('are', 'bloom') {'END': 1.0}
# ('which', 'are') {'bloom': 1.0}
# ('a', 'featherhammer') {'gives': 1.0}
# ('featherhammer', 'gives') {'a': 1.0}
# ('gives', 'a') {'double': 1.0}
# ('double', 'knock') {'END': 1.0}
# ('a', 'double') {'knock': 1.0}
# ('this', 'eden') {'day': 1.0}
# ('eden', 'day') {'is': 1.0}
# ('day', 'is') {'done': 1.0}
# ('is', 'done') {'at': 1.0}
# ('done', 'at') {'two': 1.0}
# ('two', 'oclock') {'END': 1.0}
# ('at', 'two') {'oclock': 1.0}
# ('of', 'winter') {'day': 1.0}
# ('winter', 'day') {'might': 1.0}
# ('day', 'might') {'seem': 1.0}
# ('might', 'seem') {'too': 1.0}
# ('seem', 'too') {'short': 1.0}
# ('it', 'worth') {'lifes': 1.0}
# ('worth', 'lifes') {'while': 1.0}
# ('lifes', 'while') {'to': 1.0}
# ('while', 'to') {'wake': 1.0}
# ('to', 'wake') {'and': 1.0}
# ('and', 'sport') {'END': 1.0}
# ('wake', 'and') {'sport': 1.0}

# %%
def generate():
  
  for i in range(40):
    sentence = []

    #initial word
    w0 = sample_word(initial)
    sentence.append(w0)

    #second word
    w1 = sample_word(first_order[w0])
    sentence.append(w1)

    # second order transition until END
    while True:
      w2 = sample_word(second_order[(w0,w1)])

      if w2 == 'END':
        break
      sentence.append(w2)

      w0 = w1
      w1 = w2
    
    
  print( ' '.join(sentence))

# %%
generate()
# Out:
# this is the last of it all is out of such a mess
